# %% [markdown]
# <a href="https://colab.research.google.com/github/mshumer/OpenDeepResearcher/blob/main/open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /opt/homebrew/lib/python3.11/site-packages (1.6.0)

# %%
import trafilatura
import asyncio
import aiohttp
import json

# =======================
# Configuration Constants
# =======================
DEEPSEEK_API_KEY = "sk-a8329729fedd4213afee0cbb7361d9aa" # Replace with your DEEPSEEK API key


# Endpoints
#DEEPSEEK_URL = "https://api.siliconflow.cn/v1/chat/completions"
DEEPSEEK_URL = "https://dashscope.aliyuncs.com/compatible-mode/v1/chat/completions"

SEARXNG_INSTANCE = "http://localhost:18888"  # 选择一个可用的 SearXNG 实例 参考：https://searx.space/ 或者本地部署：docker run -d --name searxng -p 8888:8080 searxng/searxng

# Default LLM model (can be changed if desired)
#DEFAULT_MODEL = "deepseek-ai/DeepSeek-V3"
DEFAULT_MODEL = "qwen-plus"

# ============================
# Asynchronous Helper Functions
# ============================

async def call_openrouter_async(session, messages, model=DEFAULT_MODEL):
    """
    Asynchronously call the OpenRouter chat completion API with the provided messages.
    Returns the content of the assistant’s reply.
    """
    headers = {
        "Authorization": f"Bearer {DEEPSEEK_API_KEY}",
        "X-Title": "OpenDeepResearcher, by Matt Shumer",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": messages
    }
    try:
        async with session.post(DEEPSEEK_URL, headers=headers, json=payload) as resp:
            if resp.status == 200:
                result = await resp.json()
                try:
                    return result['choices'][0]['message']['content']
                except (KeyError, IndexError) as e:
                    print("Unexpected OpenRouter response structure:", result)
                    return None
            else:
                text = await resp.text()
                print(f"OpenRouter API error: {resp.status} - {text}")
                return None
    except Exception as e:
        print("Error calling OpenRouter:", e)
        return None


async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            search_queries = eval(response)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    params = {"q": query, "format": "json"}
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
    }
    try:
        async with session.get(SEARXNG_INSTANCE + "/search", params=params, headers=headers) as resp:
            if resp.status == 200:
                data = await resp.json()
                links = [result["url"] for result in data.get("results", [])]
                return links
            else:
                print(f"SearXNG error: {resp.status}")
                return []
    except Exception as e:
        print("Error performing SearXNG search:", e)
        return []

async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await call_openrouter_async(session, messages)
    return report


async def fetch_webpage_text_async(link):
    """
    使用 trafilatura 异步提取网页主要内容。
    """
    loop = asyncio.get_event_loop()
    downloaded = await loop.run_in_executor(None, trafilatura.fetch_url, link)
    if downloaded:
        text = await loop.run_in_executor(None, trafilatura.extract, downloaded)
        return text
    return None

async def process_link(session, link, user_query, search_query):
    """
    处理单个链接：获取内容，判断是否有用，并提取相关上下文。
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(link)
    if not page_text:
        print(f"Failed to extract content from: {link}")
        return None

    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")

    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context

    return None

    
# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic:  对过去一年 AI 全球 大模型发展进行分析，说明DeepSeek 目前竞争力究竟如何？
# Enter maximum number of iterations (default 10):  1
# === Iteration 1 ===
# Aggregated 158 unique links from this iteration.
# Fetching content from: https://blog.csdn.net/youmaob/article/details/139004966
# Fetching content from: http://soso.dj/ockoj
# Fetching content from: https://zhuanlan.zhihu.com/p/675709137
# Fetching content from: http://giva.pl/ogicafcu
# Fetching content from: https://www.thepaper.cn/newsdetail_forward_29874089
# Fetching content from: http://lazec.fi/ge
# Fetching content from: https://xueshu.baidu.com/usercenter/paper/show?paperid=1j6m0ma04h100tw0cm0u0t40c2534092&site=xueshu_se
# Fetching content from: http://denlud.tk/gadtus
# Fetching content from: https://user.guancha.cn/main/content?id=1361513
# Fetching content from: https://www.thepaper.cn/newsDetail_forward_29237043
# Fetching content from: https://www.aixinzhijie.com/article/6842566
# Fetching content from: https://www.36kr.com/p/2626897088151816
# Fetching content from: https://www.bsia.org.cn/site/content/26590.html
# Fetching content from: https://m.thepaper.cn/baijiahao_25337193
# Fetching content from: http://www.impcia.net/artificial/details_79.html
# Fetching content from: https://www.huxiu.com/article/957075.html
# Fetching content from: https://m.thepaper.cn/newsDetail_forward_26917259
# Fetching content from: https://blog.csdn.net/2401_85773741/article/details/144087475
# Fetching content from: http://mujwimi.tk/pog
# Fetching content from: https://d.wanfangdata.com.cn/periodical/Ch9QZXJpb2RpY2FsQ0hJTmV3UzIwMjQxMTA1MTcxMzA0EhBndHp5eHhoMjAyNDA0MDAxGghxb2J1ZHNjZA%3D%3D
# Fetching content from: http://ofejizo.bn/dir
# Fetching content from: https://zhuanlan.zhihu.com/p/638455866
# Fetching content from: http://li.me/itsum
# Fetching content from: https://qikan.cqvip.com/Qikan/Article/Detail?id=7109901016
# Fetching content from: http://bofidbeb.ai/go
# Fetching content from: https://xueqiu.com/1527849020/319076533
# Fetching content from: http://husde.pn/osucuf
# Fetching content from: https://blog.csdn.net/2401_84205765/article/details/143876769
# Fetching content from: http://efe.bg/ib
# Fetching content from: http://www.aigct.org.cn/article_download/show/271
# Fetching content from: https://www.aisharenet.com/2024nianduzhongwendaai/
# Fetching content from: https://news.qq.com/rain/a/20230328A033MZ00
# Fetching content from: https://finance.sina.com.cn/tech/roll/2024-03-27/doc-inaptuyt5611697.shtml
# Fetching content from: https://aitool.csdn.net/66a8b908c0533030b8908368.html
# Fetching content from: https://www.chat2024.cn/2024/12/02/damoxing/36291/
# Fetching content from: https://news.sciencenet.cn/htmlnews/2023/11/513225.shtm
# Fetching content from: https://www.chat2024.cn/2024/10/17/damoxing/15491/
# Fetching content from: https://m.huxiu.com/article/957075.html
# Fetching content from: https://blog.csdn.net/qq_30776829/article/details/138141880
# Fetching content from: https://blog.csdn.net/m0_59235945/article/details/141939260
# Fetching content from: https://www.dw.com/zh-hant/%E5%B0%88%E8%A8%AAdeepseek%E7%82%BA%E4%BD%95%E8%83%BD%E5%9C%A8ai%E5%A4%A7%E6%A8%A1%E5%9E%8B%E4%B8%AD%E8%84%AB%E7%A9%8E%E8%80%8C%E5%87%BA/a-71481279
# Fetching content from: https://www.businessweekly.com.tw/business/blog/3017760
# Fetching content from: https://www.voachinese.com/a/deepseek-china-us-20250127/7952341.html
# Fetching content from: https://www.reccessary.com/zh-tw/news/world-technology/DeepSeek-lower-cost-AI-model-compete-ChatGPT
# Fetching content from: https://uanalyze.com.tw/articles/3737710089
# Fetching content from: https://www.cw.com.tw/article/5133932
# Fetching content from: https://www.facebook.com/businessfocus.io/posts/deepseek%E9%87%8D%E5%A1%91%E5%B8%82%E5%A0%B4%E8%AA%8D%E7%9F%A5-ai%E7%95%8C%E7%AB%B6%E7%88%AD%E4%B8%A6%E9%9D%9E%E9%9B%B6%E5%92%8C%E9%81%8A%E6%88%B2-%E7%9B%B4%E6%8E%A5%E6%AF%94%E8%BC%83meta-openai%E8%A8%93%E7%B7%B4%E6%88%90%E6%9C%AC%E4%B8%8D%E5%90%88%E7%90%86%E9%97%9C%E6%96%BC%E5%BC%95%E7%99%BC%E6%AD%A4%E6%AC%A1%E5%B8%82%E5%A0%B4%E6%B3%A2%E5%8B%95%E7%9A%84deepseek%E5%A4%A7%E8%AA%9E%E8%A8%80%E6%A8%A1%E5%9E%8B%E6%88%91%E8%AA%8D%E7%82%BA%E6%9C%89%E5%BF%85%E8%A6%81%E8%AA%AA/893085303033434/
# Fetching content from: https://www.perform-global.com/blog/ai-deepseek-open-source
# Fetching content from: https://www.bbc.com/zhongwen/articles/c2d3n28dnwlo/trad
# Fetching content from: https://cloud.tencent.com/developer/article/2482827
# Fetching content from: http://sehovit.ls/aboikace
# Fetching content from: http://gi.mx/sib
# Fetching content from: https://tenten.co/learning/deepseek-review/
# Fetching content from: http://viechu.ao/siuhke
# Fetching content from: https://www.thepaper.cn/newsDetail_forward_30042536
# Fetching content from: http://ot.be/mufedo
# Fetching content from: http://jivebde.ml/tapazhir
# Fetching content from: https://news.qq.com/rain/a/20241227A057SE00
# Fetching content from: http://cinsicleb.fi/monzol
# Fetching content from: https://www.bbc.com/zhongwen/articles/cq5gj674ql8o/trad
# Fetching content from: http://ivari.ae/daflidab
# Fetching content from: https://xueqiu.com/4290256430/318707201
# Fetching content from: http://jeguwu.bf/tadepca
# Fetching content from: https://www.cnn.com/2025/01/27/tech/deepseek-ai-explainer/index.html
# Fetching content from: http://gaz.vg/esa
# Fetching content from: https://idataagent.com/2025/01/30/deepseek-innovation-and-competitive-analysis-leading-the-new-era-of-ai/
# Fetching content from: http://bommah.uk/jaili
# Fetching content from: http://guba.eastmoney.com/news,839493,1513214247.html
# Fetching content from: https://www.iimedia.cn/c880/104316.html
# Fetching content from: https://13115299.s21i.faiusr.com/61/1/ABUIABA9GAAgss6pogYouLHDmAM.pdf
# Fetching content from: https://www.jiemian.com/article/10719646.html
# Fetching content from: https://www.huaon.com/channel/trend/970816.html
# Fetching content from: https://k.sina.com.cn/article_1850649324_6e4eaaec00101nzpa.html
# Fetching content from: https://finance.sina.cn/2024-01-24/detail-inaeqyrh2381479.d.html?from=wap
# Fetching content from: https://www.iimedia.cn/c1088/104519.html
# Fetching content from: https://pdf.dfcfw.com/pdf/H3_AP202408161639300547_1.pdf?1723798416000.pdf
# Fetching content from: https://www.frostchina.com/content/insight/detail?id=6448f485fc463e5d0942d40a
# Fetching content from: http://vec.mc/sosjipraw
# Fetching content from: https://www.iimedia.cn/c400/104152.html
# Fetching content from: http://sa.me/luwwuer
# Fetching content from: http://wirtak.il/vokfoli
# Fetching content from: https://zhuanlan.zhihu.com/p/714279967
# Fetching content from: http://ufsisog.sk/sonowlab
# Fetching content from: https://news.qq.com/rain/a/20240206A046YU00
# Fetching content from: http://vesor.re/diojo
# Fetching content from: https://www.inspur.com/lcjtww/resource/cms%20/article/2448319/2734787/2022122601.pdf
# Fetching content from: https://finance.sina.com.cn/roll/2024-12-30/doc-inecfepc3793118.shtml
# Fetching content from: https://www.mckinsey.com.cn/wp-content/uploads/2023/09/%E7%94%9F%E6%88%90%E5%BC%8FAI%E7%9A%84%E7%AA%81%E7%A0%B4%E4%B9%8B%E5%B9%B4_2023-%E9%87%91%E8%9E%8D%E5%AD%A3%E5%88%8AGenAI0908.pdf
# Fetching content from: https://www.aiust.com/article/20240328/1663.html
# Fetching content from: https://www.shujiaowang.cn/uploads/20230518/f029662e118353eb7a2125a36926956b.pdf
# Fetching content from: https://m.ofweek.com/ai/2023-12/ART-201718-8420-30620738.html
# Fetching content from: https://www.bianews.com/news/details?id=202504
# Fetching content from: https://www.frostchina.com/content/insight/detail/67346fe60bc989123b87e56d
# Fetching content from: http://ippub.ma/dadejo
# Fetching content from: http://iwaijezu.sj/mohuwha
# Fetching content from: https://www.woshipm.com/share/6146628.html
# Fetching content from: http://meesa.cy/dusput
# Fetching content from: https://www.thepaper.cn/newsDetail_forward_24006339
# Fetching content from: http://walehih.tj/pamu
# Fetching content from: https://finance.sina.com.cn/jjxw/2024-01-24/doc-inaeqyrh2381479.shtml
# Fetching content from: http://rufuce.mp/tisewe
# Fetching content from: https://m.chinabgao.com/freereport/95491.html
# Fetching content from: https://img.frostchina.com/attachment/16981632/vnGSu2oW8yYR5SnJzA74iD.pdf
# Fetching content from: https://www.jiemian.com/article/11099516.html
# Fetching content from: https://m.ofweek.com/ai/2024-05/ART-201718-8420-30634913.html
# Fetching content from: https://www.szw.org.cn/20241024/67950.html
# Fetching content from: https://www.leadleo.com/report/reading?id=660120845e81457a76b73e94
# Fetching content from: https://developer.aliyun.com/article/1638376
# Fetching content from: https://www.53ai.com/news/LargeLanguageModel/2024082231267.html
# Fetching content from: https://m.huxiu.com/article/3096977.html
# Fetching content from: https://www.da-vinci.com.tw/cn/blog/deepseek
# Fetching content from: https://cloud.tencent.com/developer/news/2132028
# Fetching content from: https://www.bbc.com/zhongwen/articles/c2d3n28dnwlo/simp
# Fetching content from: https://blog.csdn.net/2401_82648291/article/details/145415102
# Fetching content from: https://www.jiqizhixin.com/articles/2025-01-21-5
# Fetching content from: https://www.dw.com/zh/%E4%B8%93%E8%AE%BFdeepseek%E4%B8%BA%E4%BD%95%E8%83%BD%E5%9C%A8ai%E5%A4%A7%E6%A8%A1%E5%9E%8B%E4%B8%AD%E8%84%B1%E9%A2%96%E8%80%8C%E5%87%BA/a-71481279
# Fetching content from: https://www.53ai.com/news/OpenSourceLLM/2025012180142.html
# Fetching content from: https://news.qq.com/rain/a/20250205A05CD200
# Fetching content from: https://finance.sina.com.cn/roll/2025-01-23/doc-inefxxux6057875.shtml
# Fetching content from: https://www.dayanzai.me/deepseek-differs.html
# Fetching content from: http://pigpu.gi/amlefu
# Fetching content from: http://wa.no/enakezdu
# Fetching content from: http://jjsoho.com/deepseek/
# Fetching content from: http://rin.nf/vijuoj
# Fetching content from: https://aipure.ai/cn/articles/deepseek-r1-vs-openai-o1-a-comprehensive-comparison-of-open-source-and-proprietary-ai-models
# Fetching content from: http://erarosiw.pk/fufad
# Fetching content from: https://cloud.tencent.com/developer/article/2492400
# Fetching content from: http://roesu.ch/ji
# Fetching content from: https://wallstreetcn.com/articles/3740193
# Fetching content from: https://blog.creaders.net/u/33393/202501/506796.html
# Fetching content from: https://blog.csdn.net/Z_oioihoii/article/details/144947450
# Fetching content from: https://blog.csdn.net/2202_75361164/article/details/145405622
# Fetching content from: https://finance.sina.com.cn/stock/usstock/c/2025-01-27/doc-inehmkuy7811061.shtml?finpagefr=p_108
# Fetching content from: https://monica.im/zh_CN/ai-models/deepseek
# Fetching content from: https://www.wenxuecity.com/news/2025/01/27/125979685.html
# Fetching content from: http://m.chinaaet.com/article/3000169958
# Fetching content from: https://www.aihub.cn/tools/llm/deepseek-v3/
# Fetching content from: https://blog.csdn.net/dengdeng333/article/details/145433359
# Fetching content from: http://racebo.co.uk/ziw
# Fetching content from: http://de.bt/zilohkic
# Fetching content from: https://www.vzkoo.com/read/20241231a8dd279c0d46ace368a1270f.html
# Fetching content from: http://ugafez.ae/egules
# Fetching content from: https://zhuanlan.zhihu.com/p/15439546203
# Fetching content from: http://gu.bn/jitelnu
# Fetching content from: https://blog.csdn.net/gitblog_02080/article/details/144501228
# Fetching content from: http://toez.bj/cauroza
# Fetching content from: https://www.enanyang.my/node/648540
# Fetching content from: https://www.guancha.cn/internation/2025_01_29_763601.shtml
# Fetching content from: https://baike.baidu.com/item/DeepSeek/65258669
# Fetching content from: https://blog.csdn.net/zhouzongxin94/article/details/144820369
# Fetching content from: https://mofcloud.cn/blog/blog/2025-01-02-deepseek-v3/
# Fetching content from: https://finance.sina.com.cn/roll/2025-01-28/doc-inehpccz7710318.shtml
# Fetching content from: https://36kr.com/p/3135022841879040
# Fetching content from: https://wallstreetcn.com/articles/3740144
# Fetching content from: https://www.explinks.com/blog/deepseek-v2-how-strong-is-it-lets-test-with-an-ai-coding-agent-with-detailed-code/
# Fetching content from: https://ai-bot.cn/deepseek-v3/
# Fetching content from: https://news.qq.com/rain/a/20240717A06YVA00
# Fetching content from: https://blog.aihubplus.com/post/deepseek-models/
# Failed to extract content from: http://denlud.tk/gadtus
# Failed to extract content from: https://zhuanlan.zhihu.com/p/675709137
# Failed to extract content from: http://mujwimi.tk/pog
# Failed to extract content from: http://soso.dj/ockoj
# Failed to extract content from: http://ofejizo.bn/dir
# Failed to extract content from: https://zhuanlan.zhihu.com/p/638455866
# Failed to extract content from: http://lazec.fi/ge
# Failed to extract content from: http://bofidbeb.ai/go
# Failed to extract content from: https://qikan.cqvip.com/Qikan/Article/Detail?id=7109901016
# Failed to extract content from: http://husde.pn/osucuf
# Failed to extract content from: http://efe.bg/ib
# Failed to extract content from: http://gi.mx/sib
# Failed to extract content from: http://viechu.ao/siuhke
# Failed to extract content from: http://jivebde.ml/tapazhir
# Failed to extract content from: http://li.me/itsum
# Failed to extract content from: http://cinsicleb.fi/monzol
# Failed to extract content from: http://ivari.ae/daflidab
# Failed to extract content from: http://jeguwu.bf/tadepca
# Failed to extract content from: http://sehovit.ls/aboikace
# Failed to extract content from: http://bommah.uk/jaili
# Failed to extract content from: http://vec.mc/sosjipraw
# Failed to extract content from: http://wirtak.il/vokfoli
# Failed to extract content from: http://ufsisog.sk/sonowlab
# Failed to extract content from: https://zhuanlan.zhihu.com/p/714279967
# Failed to extract content from: http://vesor.re/diojo
# Failed to extract content from: http://ippub.ma/dadejo
# Failed to extract content from: http://iwaijezu.sj/mohuwha
# Failed to extract content from: http://meesa.cy/dusput
# Failed to extract content from: http://walehih.tj/pamu
# Failed to extract content from: http://rufuce.mp/tisewe
# Failed to extract content from: https://www.leadleo.com/report/reading?id=660120845e81457a76b73e94
# Failed to extract content from: https://www.voachinese.com/a/deepseek-china-us-20250127/7952341.html
# Failed to extract content from: https://www.dw.com/zh-hant/%E5%B0%88%E8%A8%AAdeepseek%E7%82%BA%E4%BD%95%E8%83%BD%E5%9C%A8ai%E5%A4%A7%E6%A8%A1%E5%9E%8B%E4%B8%AD%E8%84%AB%E7%A9%8E%E8%80%8C%E5%87%BA/a-71481279
# Failed to extract content from: http://pigpu.gi/amlefu
# Failed to extract content from: https://www.businessweekly.com.tw/business/blog/3017760
# Failed to extract content from: http://erarosiw.pk/fufad
# Failed to extract content from: https://www.cw.com.tw/article/5133932
# Failed to extract content from: https://www.facebook.com/businessfocus.io/posts/deepseek%E9%87%8D%E5%A1%91%E5%B8%82%E5%A0%B4%E8%AA%8D%E7%9F%A5-ai%E7%95%8C%E7%AB%B6%E7%88%AD%E4%B8%A6%E9%9D%9E%E9%9B%B6%E5%92%8C%E9%81%8A%E6%88%B2-%E7%9B%B4%E6%8E%A5%E6%AF%94%E8%BC%83meta-openai%E8%A8%93%E7%B7%B4%E6%88%90%E6%9C%AC%E4%B8%8D%E5%90%88%E7%90%86%E9%97%9C%E6%96%BC%E5%BC%95%E7%99%BC%E6%AD%A4%E6%AC%A1%E5%B8%82%E5%A0%B4%E6%B3%A2%E5%8B%95%E7%9A%84deepseek%E5%A4%A7%E8%AA%9E%E8%A8%80%E6%A8%A1%E5%9E%8B%E6%88%91%E8%AA%8D%E7%82%BA%E6%9C%89%E5%BF%85%E8%A6%81%E8%AA%AA/893085303033434/
# Failed to extract content from: https://www.bbc.com/zhongwen/articles/c2d3n28dnwlo/trad
# Failed to extract content from: http://roesu.ch/ji
# Failed to extract content from: https://www.bbc.com/zhongwen/articles/cq5gj674ql8o/trad
# Failed to extract content from: http://racebo.co.uk/ziw
# Failed to extract content from: http://rin.nf/vijuoj
# Failed to extract content from: http://ugafez.ae/egules
# Failed to extract content from: https://zhuanlan.zhihu.com/p/15439546203
# Failed to extract content from: http://de.bt/zilohkic
# Failed to extract content from: http://gu.bn/jitelnu
# Failed to extract content from: http://toez.bj/cauroza
# Failed to extract content from: https://www.36kr.com/p/2626897088151816
# Failed to extract content from: http://gaz.vg/esa
# Failed to extract content from: http://guba.eastmoney.com/news,839493,1513214247.html
# Failed to extract content from: http://ot.be/mufedo
# Failed to extract content from: https://13115299.s21i.faiusr.com/61/1/ABUIABA9GAAgss6pogYouLHDmAM.pdf
# Failed to extract content from: https://pdf.dfcfw.com/pdf/H3_AP202408161639300547_1.pdf?1723798416000.pdf
# Failed to extract content from: https://img.frostchina.com/attachment/16981632/vnGSu2oW8yYR5SnJzA74iD.pdf
# Failed to extract content from: https://www.shujiaowang.cn/uploads/20230518/f029662e118353eb7a2125a36926956b.pdf
# Failed to extract content from: https://36kr.com/p/3135022841879040
# Failed to extract content from: https://news.qq.com/rain/a/20240717A06YVA00
# Page usefulness for http://giva.pl/ogicafcu: No
# Page usefulness for https://d.wanfangdata.com.cn/periodical/Ch9QZXJpb2RpY2FsQ0hJTmV3UzIwMjQxMTA1MTcxMzA0EhBndHp5eHhoMjAyNDA0MDAxGghxb2J1ZHNjZA%3D%3D: No
# Page usefulness for http://wa.no/enakezdu: No
# Page usefulness for https://xueshu.baidu.com/usercenter/paper/show?paperid=1j6m0ma04h100tw0cm0u0t40c2534092&site=xueshu_se: Yes
# Page usefulness for https://www.frostchina.com/content/insight/detail?id=6448f485fc463e5d0942d40a: Yes
# Page usefulness for https://www.53ai.com/news/LargeLanguageModel/2024082231267.html: Yes
# Page usefulness for https://www.frostchina.com/content/insight/detail/67346fe60bc989123b87e56d: No
# Page usefulness for https://www.chat2024.cn/2024/12/02/damoxing/36291/: Yes
# Page usefulness for https://www.chat2024.cn/2024/10/17/damoxing/15491/: Yes
# Page usefulness for https://news.qq.com/rain/a/20250205A05CD200: Yes
# Page usefulness for https://uanalyze.com.tw/articles/3737710089: Yes
# Page usefulness for https://www.iimedia.cn/c1088/104519.html: No
# Page usefulness for https://m.chinabgao.com/freereport/95491.html: No
# Page usefulness for https://blog.csdn.net/zhouzongxin94/article/details/144820369: Yes
# Page usefulness for https://cloud.tencent.com/developer/news/2132028: Yes
# Page usefulness for https://finance.sina.com.cn/stock/usstock/c/2025-01-27/doc-inehmkuy7811061.shtml?finpagefr=p_108: Yes
# Page usefulness for https://www.szw.org.cn/20241024/67950.html: Yes
# Page usefulness for https://wallstreetcn.com/articles/3740144: Yes
# Page usefulness for https://developer.aliyun.com/article/1638376: Yes
# Page usefulness for https://blog.csdn.net/Z_oioihoii/article/details/144947450: Yes
# Page usefulness for https://finance.sina.com.cn/roll/2025-01-28/doc-inehpccz7710318.shtml: Yes
# Page usefulness for https://www.woshipm.com/share/6146628.html: Yes
# Page usefulness for https://finance.sina.com.cn/roll/2024-12-30/doc-inecfepc3793118.shtml: No
# Page usefulness for https://www.aisharenet.com/2024nianduzhongwendaai/: Yes
# Page usefulness for https://www.huaon.com/channel/trend/970816.html: Yes
# Page usefulness for https://m.thepaper.cn/baijiahao_25337193: Yes
# Page usefulness for https://mofcloud.cn/blog/blog/2025-01-02-deepseek-v3/: Yes
# Page usefulness for https://www.guancha.cn/internation/2025_01_29_763601.shtml: Yes
# Page usefulness for https://blog.csdn.net/dengdeng333/article/details/145433359: Yes
# Page usefulness for https://www.iimedia.cn/c880/104316.html: No
# Page usefulness for https://www.thepaper.cn/newsDetail_forward_30042536: Yes
# Page usefulness for https://cloud.tencent.com/developer/article/2492400: Yes
# Page usefulness for https://www.aihub.cn/tools/llm/deepseek-v3/: Yes
# Page usefulness for https://wallstreetcn.com/articles/3740193: Yes
# Page usefulness for https://m.thepaper.cn/newsDetail_forward_26917259: Yes
# Page usefulness for https://www.thepaper.cn/newsDetail_forward_24006339: Yes
# Page usefulness for http://www.impcia.net/artificial/details_79.html: Yes
# Page usefulness for https://news.qq.com/rain/a/20241227A057SE00: Yes
# Page usefulness for https://k.sina.com.cn/article_1850649324_6e4eaaec00101nzpa.html: Yes
# Page usefulness for https://www.thepaper.cn/newsDetail_forward_29237043: Yes
# Page usefulness for https://www.dayanzai.me/deepseek-differs.html: Yes
# Page usefulness for https://ai-bot.cn/deepseek-v3/: Yes
# Page usefulness for https://blog.csdn.net/gitblog_02080/article/details/144501228: Yes
# Page usefulness for https://www.jiemian.com/article/10719646.html: Yes
# Page usefulness for https://finance.sina.com.cn/tech/roll/2024-03-27/doc-inaptuyt5611697.shtml: Yes
# Page usefulness for https://m.ofweek.com/ai/2023-12/ART-201718-8420-30620738.html: No
# Page usefulness for https://m.ofweek.com/ai/2024-05/ART-201718-8420-30634913.html: Yes
# Page usefulness for https://blog.csdn.net/2401_82648291/article/details/145415102: Yes
# Page usefulness for https://www.cnn.com/2025/01/27/tech/deepseek-ai-explainer/index.html: Yes
# Page usefulness for https://aipure.ai/cn/articles/deepseek-r1-vs-openai-o1-a-comprehensive-comparison-of-open-source-and-proprietary-ai-models: Yes
# Page usefulness for https://xueqiu.com/4290256430/318707201: Yes
# Page usefulness for https://www.perform-global.com/blog/ai-deepseek-open-source: Yes
# Page usefulness for https://blog.csdn.net/2401_85773741/article/details/144087475: Yes
# Page usefulness for https://www.jiqizhixin.com/articles/2025-01-21-5: Yes
# Page usefulness for https://finance.sina.com.cn/jjxw/2024-01-24/doc-inaeqyrh2381479.shtml: Yes
# Page usefulness for https://blog.csdn.net/qq_30776829/article/details/138141880: Yes
# Page usefulness for https://finance.sina.cn/2024-01-24/detail-inaeqyrh2381479.d.html?from=wap: Yes
# Page usefulness for https://news.sciencenet.cn/htmlnews/2023/11/513225.shtm: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"b45621f1-c95f-90cd-b37f-8a5f566673b5"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"4d0b3542-de64-9bba-a336-f31df4fa4a42"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"802c2371-8c82-9bb6-b9c4-85d2d324c78b"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"b8b14f69-1bb8-9936-98cb-a8d3d6acee06"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"36957ed5-dadf-9022-bedb-44725e6009f7"}
# Page usefulness for https://www.bsia.org.cn/site/content/26590.html: No
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"ebfa5a4f-5733-9c62-b1d1-512ab8bd0be3"}
# Page usefulness for http://m.chinaaet.com/article/3000169958: Yes
# Page usefulness for https://tenten.co/learning/deepseek-review/: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"06eb1314-355d-9451-8339-070bc5a390f5"}
# Page usefulness for https://cloud.tencent.com/developer/article/2482827: No
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"e3414fec-c13f-912f-96d3-53a1c620e4b0"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"603e2fea-fb69-978c-a430-f0b7cb800749"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"32fc9915-c4f0-997d-a8be-2222397c9099"}
# Page usefulness for https://www.bianews.com/news/details?id=202504: No
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"b1959e31-f0e1-9e68-a1d9-265f29bf9e5d"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"0c56dc72-8ab2-953f-a167-c49442eb7106"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"da40fe7c-2ffb-9446-b38b-7edf8b657359"}
# Page usefulness for https://idataagent.com/2025/01/30/deepseek-innovation-and-competitive-analysis-leading-the-new-era-of-ai/: No
# Page usefulness for https://blog.aihubplus.com/post/deepseek-models/: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"f54afc1c-5309-9bc8-98cf-711266b30fec"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"6162d6cd-5fc7-963a-9c14-f90e4ec0cb55"}
# Page usefulness for https://www.vzkoo.com/read/20241231a8dd279c0d46ace368a1270f.html: No
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"de3e6c09-1650-914f-9736-7f6429d21385"}
# Page usefulness for https://xueqiu.com/1527849020/319076533: No
# Page usefulness for https://www.da-vinci.com.tw/cn/blog/deepseek: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"3803b713-0ef1-96c8-bc5b-ecddcc4a0138"}
# Page usefulness for https://blog.csdn.net/m0_59235945/article/details/141939260: No
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"282e2866-3710-93cb-92c5-62d6518c0128"}
# Page usefulness for https://user.guancha.cn/main/content?id=1361513: No
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"438b8c47-2ec6-9f72-8378-815ee449de05"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"a5d2170a-dc11-9756-975e-11a36eeb890c"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"cfb1b1a2-4856-92f3-8858-3aea627960ce"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"758c1c7a-b593-9eb3-b8ac-78e1758b85d2"}
# Page usefulness for https://blog.csdn.net/2401_84205765/article/details/143876769: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"56168ad1-23c7-9e6b-972b-b665c45c39bf"}
# Page usefulness for https://aitool.csdn.net/66a8b908c0533030b8908368.html: No
# Page usefulness for http://jjsoho.com/deepseek/: Yes
# Page usefulness for https://www.explinks.com/blog/deepseek-v2-how-strong-is-it-lets-test-with-an-ai-coding-agent-with-detailed-code/: Yes
# Page usefulness for https://baike.baidu.com/item/DeepSeek/65258669: Yes
# Page usefulness for https://m.huxiu.com/article/957075.html: No
# Page usefulness for https://m.huxiu.com/article/3096977.html: Yes
# Page usefulness for https://www.aixinzhijie.com/article/6842566: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"9c6ab85d-0cc3-934a-afd0-3deedc5045bf"}
# Page usefulness for https://www.aiust.com/article/20240328/1663.html: Yes
# Page usefulness for https://finance.sina.com.cn/roll/2025-01-23/doc-inefxxux6057875.shtml: Yes
# Page usefulness for https://www.jiemian.com/article/11099516.html: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"1c9a5dcf-5235-912d-824a-2cf516f91b04"}
# Failed to extract content from: http://sa.me/luwwuer
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"ed162f2f-f420-9b08-87b6-b4fb063d4162"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"4b4ff88c-1e1f-9032-831c-2cf6b5782588"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"29d5557f-cd82-9555-a082-3b6bf7214d5b"}
# Page usefulness for https://www.thepaper.cn/newsdetail_forward_29874089: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"68d4fd52-eed7-9cb0-8d32-a30b9a29b7ab"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"65d62d4e-1351-90cb-8a42-664988d5d21d"}
# Page usefulness for https://blog.csdn.net/2202_75361164/article/details/145405622: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"da14f1bb-9956-9d0e-84c3-3793e6060015"}
# Page usefulness for http://www.aigct.org.cn/article_download/show/271: Yes
# Page usefulness for https://www.53ai.com/news/OpenSourceLLM/2025012180142.html: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"3de95c7a-a9ca-9f63-94f4-4e36fd2f62f2"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"3b1ae3cf-57c1-933f-9166-31d0040e755b"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"5786a9b1-d220-997c-822f-de9610b823d6"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"e663d935-9bbb-9e75-9d4e-c5597ed2b168"}
# Page usefulness for https://www.huxiu.com/article/957075.html: Yes
# Page usefulness for https://news.qq.com/rain/a/20240206A046YU00: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"1e6bb5d8-0d04-975e-bbc1-798a867d3daf"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"5098ba65-827a-9b8a-8475-01989f681824"}
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"0319b49b-b795-9463-a6ec-fb04fdde6d29"}
# Page usefulness for https://blog.csdn.net/youmaob/article/details/139004966: Yes
# Page usefulness for https://news.qq.com/rain/a/20230328A033MZ00: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"493ae3fb-499b-9646-964b-cca265a29605"}
# Page usefulness for https://www.iimedia.cn/c400/104152.html: Yes
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"909e31a6-9164-9ded-b97d-0b524d4a8bf6"}
# Extracted context from https://www.53ai.com/news/LargeLanguageModel/2024082231267.html (first 200 chars): 谷歌反击，最强Gemini 2.0全家桶砸场DeepSeek！物理模拟编码惊人Jeff Dean站台
#
# Google Gemini 2.0 Pro来袭，DeepSeek突然觉得不香了？
#
# DeepSeek 对国内互联网巨头的影响
#
# DeepSeek R1 给我的冲击
# OpenRouter API error: 429 - {"error":{"message":"You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://help.aliyun.com/zh/dashscope/developer-reference/tongyi-thousand-questions-metering-and-billing.","type":"insufficient_quota","param":null,"code":"insufficient_quota"},"request_id":"bb122217-2d61-94dc-a9a2-d93efb675a96"}
# Extracted context from https://xueshu.baidu.com/usercenter/paper/show?paperid=1j6m0ma04h100tw0cm0u0t40c2534092&site=xueshu_se (first 200 chars): AI大模型作为当前最热门的技术领域,得到了广泛的关注.以谷歌的BERT和OpenAI的GPT为代表,模型的参数规模逐步提升至千亿甚至万亿级,训练数据量级也大幅提升,随之带来了模型能力的显著提高,掀起了国内外AI大模型的研究热潮.
#
# DeepSeek目前的竞争力信息未在提供的网页内容中提及。
# Page usefulness for https://www.inspur.com/lcjtww/resource/cms%20/article/2448319/2734787/2022122601.pdf: No
# Extracted context from https://news.qq.com/rain/a/20250205A05CD200 (first 200 chars): DeepSeek AI 公司发布推理模型R1，引发国内外关注，部分谣言对其产生误解。Tanishq Mathew Abraham 指出，DeepSeek 性能与 OpenAI 的 o1 相当，训练费用相对较低。此外，DeepSeek 推出易于使用的界面，吸引了数百万新用户加入。针对谣言，Abraham 进行了反驳，强调 DeepSeek 在工程、效率和架构创新方面的优势。尽管如此，人工智能竞赛仍在
# Extracted context from https://www.chat2024.cn/2024/12/02/damoxing/36291/ (first 200 chars): 人工智能 （AI）技术近年来飞速发展，尤其是大模型的出现和应用，成为了 AI 领域的热门话题。2024 年，我们根据最新的数据和趋势，对全球及国内 AI 大模型的排名进行了深入分析。
#
# 在 2024 年，各大 AI 公司继续加大对大模型的研发投入。根据市场调研机构的最新数据显示，目前全球 AI 大模型的排名主要是由以下几家公司主导：OpenAI 的 GPT 系列、Google 的 BERT、华为的
# Extracted context from https://k.sina.com.cn/article_1850649324_6e4eaaec00101nzpa.html (first 200 chars): 2024年，大模型市场热闹非凡，各大厂商将目光投向具体应用场景，推动行业定制化的大模型加速落地，这些模型正逐步渗透到金融、医疗、教育等多个关键行业中。Deepseek在11月20日上线了DeepSeek-R1-Lite大模型，强调大模型的逻辑思考能力。这表明Deepseek在增强其大模型的推理能力和特定场景应用方面进行了投入和改进。
#
# 与此同时，行业内对大模型的关注逐渐从单纯的参数和性能转向商业化
# Extracted context from https://www.frostchina.com/content/insight/detail?id=6448f485fc463e5d0942d40a (first 200 chars): AI 大模型最早的关注度起源于 NLP 领域，随着多模态能力的演进，CV 领域及多模态通用大模型逐渐成为发展主流。基于大模型的各类应用的爆发，尤其是生成式 AI 为用户提供了突破性的创新机会，促使大模型升级成为人类生产力工具的颠覆式革新。数据规模和参数规模的有机提升，让大模型具备了不断学习和成长的基因。大模型开始具备涌现能力，逐渐拉开了通用人工智能（AGI）的发展序幕。
#
# 为此，弗若斯特沙利文（F
# Extracted context from https://www.huaon.com/channel/trend/970816.html (first 200 chars): 中国AI大模型行业的竞争格局日益激烈，众多企业纷纷投入研发，力求在这个新兴市场中占据一席之地。目前，该行业已经初步形成了多元化的竞争格局，既有科技巨头凭借强大的技术实力和丰富的数据资源稳占鳌头，也有创新型中小企业凭借独特的技术路线和应用场景异军突起。科技巨头如百度、腾讯、阿里等凭借其在人工智能领域的深厚积累和强大的技术实力，占据了市场的主导地位。
#
# 随着人工智能技术的不断进步和应用场景的日益丰富，
# Extracted context from https://www.jiemian.com/article/10719646.html (first 200 chars): 2023年，大模型技术在全球科技界掀起了一场风暴，引发了科技巨头们的激烈角逐。这一年，大模型不仅重新定义了人工智能的边界，还催生了跨行业技术革新。
#
# 根据IDC的预测，全球AI计算市场规模将从2022年的195亿美元急剧增长至2026年的346.6亿美元，其中生成式AI市场预计增至109.9亿美元。尤其在中国市场，人工智能市场规模预计将超264亿美元。
#
# DeepSeek并未在上述内容中直接提及。
# Extracted context from https://www.chat2024.cn/2024/10/17/damoxing/15491/ (first 200 chars): AI 大模型是指利用深度学习技术构建的，具有庞大参数量和复杂架构的模型。它们在诸多应用场景中展现出超凡的学习能力，如自然语言处理、图像识别和推荐系统等。
#
# 在全球范围内，AI 大模型的竞争日趋激烈。根据最新分析，以下是 2024 年全球 AI 大模型的排名情况：
#
# 随着这些公司的不断投入和探索，预计国内 AI 大模型的应用将更为广泛，覆盖更多行业。
#
# AI 大模型的发展趋势主要体现在以下几个方面：
# Extracted context from https://www.szw.org.cn/20241024/67950.html (first 200 chars): 自2022年OpenAI发布ChatGPT以来，AI大模型逐渐走入公众视野，并在全球范围内掀起了一股热潮。2023年被视为中国大模型的发展元年，国内厂商、科技巨头、科研院所和初创公司纷纷部署自己的大模型，力图在这一领域占据一席之地。
#
# 截止2024年4月，中国的大模型数量已近200个，通用大模型数量达到40个左右。百度、阿里、华为、腾讯等科技巨头纷纷推出自己的大模型产品，科研院所和创业公司也积极参
# Extracted context from https://m.thepaper.cn/baijiahao_25337193 (first 200 chars): 自2022年11月起，以ChatGPT为典型代表的大模型在全球数字科技界引起了极大关注。全球范围内的大模型数量受其影响在不到一年的时间内就已超过一百种。
#
# 截至2023年10月，大模型技术已经步入了快速发展的阶段。在中国，超过10种大模型已完成备案。其中，百度的文心大模型升级至4.0版本后，在理解、生成、逻辑和记忆等四项核心能力上均实现了显著的提升。与此同时，OpenAI的ChatGPT也经历了一
# Extracted context from https://www.thepaper.cn/newsDetail_forward_30042536 (first 200 chars): DeepSeek和阿里巴巴在开源方面已经领先Meta，是世界范围内开源最强者之一。DeepSeek V3开创了一种新范式：不差钱的理想主义色彩的公司去训练更大更好的模型，然后开源出来，各个行业利用这个更大更好的模型去蒸馏各个领域的专用模型。
#
# DeepSeek关联公司杭州深度求索人工智能基础技术研究有限公司，注册资本1000万元，法定代表人裴湉。DeepSeek不仅完全开源，而且放出了详细的技术报
# Failed to extract content from: https://www.bbc.com/zhongwen/articles/c2d3n28dnwlo/simp
# Extracted context from https://wallstreetcn.com/articles/3740144 (first 200 chars): DeepSeek是一家中国人工智能初创公司，近期发布了新的AI模型，其中包括名为Janus-Pro和JanusFlow的一系列开源多模态AI模型。这些模型的参数大小从10亿到70亿不等，并已在Hugging Face平台上提供下载。
#
# 70亿参数的Janus-Pro-7B在图像创建能力方面声称超越了OpenAI的DALL-E 3和Stable Diffusion模型。根据文生图GenEval和DP
# Extracted context from https://www.guancha.cn/internation/2025_01_29_763601.shtml (first 200 chars): 随着关于中国人工智能大模型DeepSeek-R1的讨论不断升温，美方又开始急赤白脸了，白宫人工智能“沙皇”已经等不及要给中国泼脏水了。据福克斯新闻28日报道，当地时间周二，特朗普提名的白宫人工智能顾问大卫·萨克斯（David Sacks）接受该媒体采访时宣称，DeepSeek“有可能”窃取了美国的知识产权才得以崛起。而他所谓的“窃取”，实际上是DeepSeek-R1在训练过程中进行的“模型蒸馏”技
# Extracted context from https://blog.csdn.net/qq_30776829/article/details/138141880 (first 200 chars): 过去一年全球AI大模型发展综述：
#
# 1、ChatGPT 是人工智能公司 OpenAI 基于 GPT-3.5 研发的大规模对话式语言模型，目前处于测试阶段，拥有 OpenAI 账户即可免费使用。ChatGPT 采用对话格式，目前已经做到流利回答问题、纠正自己的错误、挑战用户提出的不正确的前提并拒绝不正当的要求，且支持中文。2023/03/15 凌晨，openAI 发布了多模态预训练大模型 GPT-4
# Failed to extract content from: https://www.dw.com/zh/%E4%B8%93%E8%AE%BFdeepseek%E4%B8%BA%E4%BD%95%E8%83%BD%E5%9C%A8ai%E5%A4%A7%E6%A8%A1%E5%9E%8B%E4%B8%AD%E8%84%B1%E9%A2%96%E8%80%8C%E5%87%BA/a-71481279
# Extracted context from https://www.thepaper.cn/newsDetail_forward_29237043 (first 200 chars): 近年来，人工智能技术，特别是AI大模型在全球范围内掀起了一股热潮。中国作为全球科技竞争的重要参与者，AI大模型的发展尤为引人注目。进入21世纪20年代，以GPT为代表的预训练大模型的出现，标志着AI大模型技术进入了新的发展阶段。
#
# 在这一阶段，中国AI大模型的发展取得了显著成果。一方面，以百度、阿里、腾讯等为代表的科技巨头纷纷推出了自己的AI大模型产品，如百度的文心一言、阿里的通义千问等。这些模型
# Extracted context from https://ai-bot.cn/deepseek-v3/ (first 200 chars): DeepSeek V3是幻方量化旗下人工智能公司深度求索开源的最新版AI模型，在多语言编程能力上的进步显著，超越了Claude 3.5 Sonnet V2等竞争对手。DeepSeek V3采用了6850亿参数的混合专家（MoE）架构，包含256个专家，使用sigmoid路由方式，每次选取前8个专家参与计算，能更高效地处理复杂任务。V3模型提升了响应速度和处理效率，生成吐字速度从20 TPS提高至6
# Extracted context from https://finance.sina.com.cn/roll/2025-01-28/doc-inehpccz7710318.shtml (first 200 chars): DeepSeek在过去一年中通过发布多个重要模型，如V3、R1以及最新的多模态模型Janus-Pro，在全球AI大模型领域迅速崛起。Janus-Pro拥有10亿和70亿参数规模，特别在文生图能力方面表现出色。根据基准测试，Janus-Pro-7B的准确率分别为80%和84.2%，超过了OpenAI DALL-E 3和Stable Diffusion等其他模型。
#
# DeepSeek的技术文档显示，J
# Extracted context from https://www.aihub.cn/tools/llm/deepseek-v3/ (first 200 chars): DeepSeek-V3 是由深度求索公司推出的一款全新发布的自研 MoE（混合专家）模型，旨在突破当前大语言模型的性能瓶颈。通过 671B 参数和 37B 激活专家，DeepSeek-V3 在 14.8T token 的大规模预训练上取得了显著进展，展现出与世界顶尖闭源模型（如 GPT-4o 和 Claude-3.5-Sonnet）相当的表现。该模型在多项标准评测中超越了 Qwen2.5-72B
# Extracted context from https://www.aisharenet.com/2024nianduzhongwendaai/ (first 200 chars): 自2023年以来，AI大模型在全球范围内掀起了有史以来规模最大的人工智能浪潮。进入2024年，全球大模型竞争态势日益加剧，随着Sora、GPT-4o、o1的发布，国内大模型在2024年进行了波澜壮阔的大模型追逐赛。
#
# 国产大模型如DeepSeek-V3、Qwen2.5-72B-Instruct和Qwen2.5-32B-Instruct在性价比上展现出极强的竞争力。在较为高水平的能力基础上能够保持极
# Extracted context from https://www.woshipm.com/share/6146628.html (first 200 chars): 自2022年11月OpenAI发布ChatGPT以来，全球AI领域掀起了一场关于大模型的热潮。大模型行业是一个快速崛起的新兴领域，经历了萌芽期、探索期，自2022年起进入迅猛发展阶段。中国大模型市场规模迅速增长，2023年已达17.65亿元，预计2030年将达896.58亿元。全国大模型相关企业近8万家，广东省、北京市、江苏省位列前三。
#
# 大模型行业面临多重挑战，包括非结构性数据的处理难题、能耗与
# Extracted context from https://uanalyze.com.tw/articles/3737710089 (first 200 chars): DeepSeek 的聊天機器人在新聞資訊準確性測試中表現不佳，準確率僅 17%，在 NewsGuard 可信度審查中排名第十，遠落後於 OpenAI 的 ChatGPT 和 Google Gemini 等西方 AI 競爭對手。根據新聞可信度評級機構 NewsGuard 週三發布的報告，DeepSeek 聊天機器人在回應新聞相關問題時，30% 的回覆包含錯誤資訊，53% 的回答則過於模糊或無實質內容
# Extracted context from http://www.impcia.net/artificial/details_79.html (first 200 chars): AI大模型是“大数据+大算力+强算法”结合的产物，参数规模实现了从亿级到百万亿级的突破。目前千亿级参数规模的大模型成为主流。Transformer架构是当前大模型领域主流的算法架构基础，几乎所有参数规模超过千亿的大型语言模型都采取GPT模式，如百度文心一言，阿里发布的通义千问等。
#
# 通用大模型是具有强大泛化能力，可在不进行微调或少量微调的情况下完成多场景任务，相当于AI完成了“通识教育”，Chat
# Extracted context from https://cloud.tencent.com/developer/article/2492400 (first 200 chars): 在当今人工智能飞速发展的时代，大模型如雨后春笋般不断涌现，它们在自然语言处理、图像识别、智能决策等众多领域发挥着至关重要的作用。DeepSeek 作为其中一颗耀眼的新星，凭借其独特的技术优势和出色的性能表现吸引了广泛关注。
#
# 训练效率是衡量一个 AI 大模型优劣的重要指标之一。它直接关系到模型的开发成本和迭代速度。以某一特定规模的数据集和相同的硬件环境为例，传统的 AI 大模型如 GPT - 3
# Failed to extract content from: https://blog.creaders.net/u/33393/202501/506796.html
# Extracted context from https://finance.sina.com.cn/jjxw/2024-01-24/doc-inaeqyrh2381479.shtml (first 200 chars): 2023年，大模型技术在全球科技界掀起了一场风暴，引发了科技巨头们的激烈角逐。这一年，大模型不仅重新定义了人工智能的边界，还催生了跨行业技术革新。
#
# 根据IDC的预测，全球AI计算市场规模将从2022年的195亿美元急剧增长至2026年的346.6亿美元，其中生成式AI市场预计增至109.9亿美元。尤其在中国市场，人工智能市场规模预计将超264亿美元。
#
# DeepSeek并非文中直接提及的公司之一
# Extracted context from https://finance.sina.com.cn/stock/usstock/c/2025-01-27/doc-inehmkuy7811061.shtml?finpagefr=p_108 (first 200 chars): DeepSeek是一家于2023年成立的中国初创企业，创始人是AI驱动量化对冲基金幻方量化的掌门人梁文锋。该公司开发开源AI模型，其移动应用程序（app）于1月初发布，然后迅速登顶美国iPhone下载榜。该app与OpenAI旗下ChatGPT等其他聊天机器人的区别是，它会在对提示做出回应之前阐明其推理过程。
#
# DeepSeek R1版本的性能与OpenAI的最新版本相当，并且允许用户利用模型输出
# Failed to extract content from: https://monica.im/zh_CN/ai-models/deepseek
# Extracted context from https://blog.csdn.net/zhouzongxin94/article/details/144820369 (first 200 chars): 深度求索公司正式推出了其最新的开源模型——DeepSeek-V3，凭借671B的参数和创新的MoE架构，迅速引起了openAI等大厂公司的关注。
#
# DeepSeek-V3在多项评测中表现出色，尤其是在与GPT-4o和Claude-3.5-Sonnet的对比中，显示出不俗的竞争力。根据独立评测机构Artificial Analysis的评估，DeepSeek-V3在质量指数上达到了80，超越了GPT
# Failed to extract content from: https://www.wenxuecity.com/news/2025/01/27/125979685.html
# Extracted context from https://cloud.tencent.com/developer/news/2132028 (first 200 chars): 近年来，人工智能技术飞速发展，各类AI模型层出不穷，其中DeepSeek作为一款新兴的AI模型，凭借其独特的技术优势和广泛的应用场景，逐渐在市场中崭露头角。
#
# ### 技术架构对比
# DeepSeek采用了一种混合架构，结合了深度学习与强化学习技术，能够更好地适应多任务处理。其模型设计注重高效性和灵活性，支持快速迭代和定制化开发。此外，DeepSeek在训练数据的选择上更加注重多样性和实用性，能够覆
# Failed to extract content from: https://www.enanyang.my/node/648540
# Extracted context from https://aipure.ai/cn/articles/deepseek-r1-vs-openai-o1-a-comprehensive-comparison-of-open-source-and-proprietary-ai-models (first 200 chars): DeepSeek-R1 是一个在中国开发的免费开源推理模型，正在挑战像 OpenAI 的 O1 这样的专有模型的主导地位。DeepSeek-R1 有 DeepSeek-R1-Zero 和 DeepSeek-R1 两个版本，发布一周内就在 GitHub 上获得了 16.3 万颗星。
#
# 该模型在数学、编程和自然语言推理等任务中表现出色，在许多基准测试中与 OpenAI 的 O1 不相上下。例如，在 A
# Extracted context from https://blog.csdn.net/gitblog_02080/article/details/144501228 (first 200 chars): DeepSeek-V2是一款强大的Mixture-of-Experts（MoE）语言模型，拥有2360亿总参数，其中210亿参数在每次推理时被激活。与前代DeepSeek 67B相比，DeepSeek-V2在性能上有了显著提升，同时节省了42.5%的训练成本，减少了93.3%的KV缓存，并将最大生成吞吐量提升了5.76倍。该模型经过大规模预训练，涵盖了8.1万亿个token，并通过监督微调（SFT
# Extracted context from https://mofcloud.cn/blog/blog/2025-01-02-deepseek-v3/ (first 200 chars): DeepSeek V3 的发布在大模型领域引起了广泛关注。这款新模型由幻方量化旗下的 DeepSeek团队推出，以其高达 6710 亿参数MoE架构的强大性能脱颖而出。不仅如此，DeepSeek V3 还通过优化计算资源实现了更低的调用成本，为企业和开发者提供了兼具高性能和高性价比的选择。在市场上与 OpenAI 的 GPT 系列和 Anthropic 的 Claude 等热门模型竞争时，Deep
# Extracted context from https://blog.csdn.net/dengdeng333/article/details/145433359 (first 200 chars): 在人工智能大模型蓬勃发展的浪潮中，DeepSeek 以其独特的技术路线和出色的性能表现脱颖而出。与主流大模型相比，DeepSeek 不仅在技术原理上有着显著的差异，还展现出了在较低算力下达到 OpenAI API 水平的卓越能力。
#
# 一、模型架构差异
# DeepSeek 则在架构上进行了创新，采用了一种更轻量化且高效的设计。它结合了基于注意力机制的改进模块，这种模块在保留 Transformer 核
# Extracted context from https://blog.csdn.net/2401_82648291/article/details/145415102 (first 200 chars): 在当今人工智能飞速发展的时代，大模型如雨后春笋般不断涌现，它们在自然语言处理、图像识别、智能决策等众多领域发挥着至关重要的作用。DeepSeek 作为其中一颗耀眼的新星，凭借其独特的技术优势和出色的性能表现吸引了广泛关注。
#
# ### 性能对比：
#
# #### 2.1 训练效率：
# 训练效率是衡量一个 AI 大模型优劣的重要指标之一。它直接关系到模型的开发成本和迭代速度。
# 以某一特定规模的数据集和相同的
# Extracted context from https://www.thepaper.cn/newsDetail_forward_24006339 (first 200 chars): 2022年底，诸如ChatGPT、Midjourney、Stable Diffusion等大型模型的相继亮相，掀开了人工智能大模型的发展热潮。国内如百度、科大讯飞、商汤等在内的一众企业也积极投入到大模型的开发与落地中来，推动市场迅速扩大。
#
# 据大模型之家测算，预计到2023年，全球人工智能大模型市场规模将达到210亿美元，并且预计随着大模型的进一步发展和技术的不断创新，为企业和组织提将供了更强大的
# Extracted context from https://news.qq.com/rain/a/20241227A057SE00 (first 200 chars): 中国人工智能公司DeepSeek发布开源大语言模型DeepSeek V3，参数规模达6710亿，超越Meta的Llama3.1。DeepSeek V3在多项基准测试中表现优于GPT-4等主流闭源模型，训练数据集包含14.8万亿token。除此之外，DeepSeek V3在长文本处理、代码生成和数学推理等领域展现顶尖性能。通过算法和工程优化，DeepSeek V3的生成速度提高至60 TPS，提升用
# Extracted context from https://www.cnn.com/2025/01/27/tech/deepseek-ai-explainer/index.html (first 200 chars): A surprisingly efficient and powerful Chinese AI model has taken the technology industry by storm. It’s called DeepSeek R1, and it’s rattling nerves on Wall Street. The new AI model was developed by D
# Extracted context from https://finance.sina.cn/2024-01-24/detail-inaeqyrh2381479.d.html?from=wap (first 200 chars): 2023年，大模型技术在全球科技界掀起了一场风暴，引发了科技巨头们的激烈角逐。这一年，大模型不仅重新定义了人工智能的边界，还催生了跨行业技术革新。
#
# 根据IDC的预测，全球AI计算市场规模将从2022年的195亿美元急剧增长至2026年的346.6亿美元，其中生成式AI市场预计增至109.9亿美元。尤其在中国市场，人工智能市场规模预计将超264亿美元。
#
# 比如OpenAI旗下的ChatGPT大模型
# Failed to extract content from: https://www.reccessary.com/zh-tw/news/world-technology/DeepSeek-lower-cost-AI-model-compete-ChatGPT
# Extracted context from https://wallstreetcn.com/articles/3740193 (first 200 chars): 春节期间，DeepSeek新一代开源模型以惊人的低成本和高性能引发热议，在全球投资界引发剧震。市场上甚至出现了DeepSeek"仅用500万美元就复制OpenAI"的说法，认为这将给整个AI基础设施产业带来“末日”。对此，华尔街知名投行伯恩斯坦在详细研究DeepSeek技术文档后发布报告称，这种市场恐慌情绪明显过度，DeepSeek用“500万美元复制OpenAI”是市场误读。
#
# 另外，该行认为，
# Extracted context from https://www.dayanzai.me/deepseek-differs.html (first 200 chars): 长期以来，人工智能（AI）行业主要由美国公司如 OpenAI、Google 和 Meta 主导。然而，近年来，中国的 AI 初创公司 DeepSeek 凭借其创新的模型和技术，迅速崛起并开始在全球 AI 市场中占据一席之地。
#
# 1. **开源模型与专有 AI**
# DeepSeek 采取了与 OpenAI 等美国 AI 巨头不同的策略，优先考虑开源开发。其最新发布的 DeepSeek-R1 模型在
# Failed to extract content from: https://www.mckinsey.com.cn/wp-content/uploads/2023/09/%E7%94%9F%E6%88%90%E5%BC%8FAI%E7%9A%84%E7%AA%81%E7%A0%B4%E4%B9%8B%E5%B9%B4_2023-%E9%87%91%E8%9E%8D%E5%AD%A3%E5%88%8AGenAI0908.pdf
# LLM provided new search queries: ['DeepSeek与国际顶尖大模型在特定行业应用中的对比分析', 'DeepSeek的开源策略对其市场竞争力的影响', 'DeepSeek在不同国家和地区的用户反馈及接受度', 'DeepSeek的技术路线对未来AI发展趋势的潜在影响']
#
# Generating final report...
#
# ==== FINAL REPORT ====
#
# # 深度分析：DeepSeek在全球AI大模型竞争中的竞争力
#
# ## 一、全球AI大模型发展概述
#
# 过去一年，人工智能大模型（AI大模型）作为技术领域的热点，吸引了全球科技巨头的广泛参与。以OpenAI的GPT系列、谷歌的BERT和PaLM 2、微软的Copilot Office、以及华为的盘古大模型为代表，这些模型在参数规模、训练数据量和性能上不断突破，推动了AI技术的快速进步。
#
# 在中国，百度、阿里、腾讯等科技巨头纷纷推出自己的AI大模型产品，如百度的文心一言、阿里的通义千问等。这些模型不仅在语言理解、生成、问答、翻译等方面表现出色，还为中国的AI产业发展注入了新的活力。同时，中国政府高度重视AI大模型的发展，出台了一系列政策措施支持AI技术的研发和应用，使得中国AI大模型市场规模迅速增长，从2020年的15亿元增长至2023年的147亿元，并预计2024年将达到216亿元。
#
# ## 二、DeepSeek公司背景与技术特点
#
# ### （一）公司背景
# DeepSeek是一家成立于2023年的中国初创企业，由AI驱动量化对冲基金幻方量化的掌门人梁文锋创立。公司专注于开发开源AI模型，其移动应用程序自发布以来迅速登顶美国iPhone下载榜，成为市场关注的焦点。
#
# ### （二）技术特点
# DeepSeek的技术核心在于其高效且创新的架构设计，尤其是在混合专家（MoE）架构的应用上。MoE架构通过每次只激活部分参数，减少了计算量，从而显著降低了训练和运行成本。此外，DeepSeek还采用了多头潜在注意力（MHLA）技术和FP8混合精度训练，进一步优化了性能表现。这些技术的综合运用，使得DeepSeek在训练时仅需同等规模开源模型约9%的算力，便能达到甚至超越其性能。
#
# ## 三、DeepSeek模型的具体表现
#
# ### （一）性能对比
# DeepSeek-V3是DeepSeek推出的最新版本，拥有6710亿参数，采用MoE架构，训练成本仅为558万美元，远低于Meta的Llama-3.1（超过5亿美元）。根据独立评测机构Artificial Analysis的评估，DeepSeek-V3在质量指数上达到了80，超越了GPT-4o和Llama 3.3 70B，仅次于谷歌的Gemini 2.0 Flash和OpenAI的o1系列模型。
#
# | 指标 | DeepSeek-V3 | GPT-4o | Claude-3.5-Sonnet |
# |---|---|---|---|
# | 参数量 | 671B | 175B | 175B |
# | 训练成本 | 558万美元 | 10亿美元 | 5亿美元 |
# | 质量指数 | 80 | 82 | 75 |
# | 每100万个Token的价格 | 0.48美元 | 18美元 | 18美元 |
# | 每秒生成Token数量 | 87.5 | 100 | 90 |
# | 首字响应时间 | 1.14秒 | 0.9秒 | 1.0秒 |
# | 上下文窗口 | 13万Token | 200万Token | 200万Token |
#
# 尽管DeepSeek-V3在多个维度表现出色，但其上下文窗口仅支持13万个Token，远低于Claude-3.5-Sonnet的200万Token。这一局限性可能会影响其在某些复杂任务中的表现，尤其是在需要处理大量上下文信息的场景中。
#
# ### （二）应用场景
# DeepSeek-V3适用于多种场景，包括智能客服、内容创作、教育辅助和数据分析等。其高效性和灵活性使其在企业级应用中具有较大优势。特别是在中文语境下的应用场景中，DeepSeek-V3的表现尤为突出，例如在C-Eval教育类测评和C-SimpleQA知识类任务中，均超过了Qwen2.5-72B等其他开源模型。
#
# ### （三）推理能力
# DeepSeek-R1在推理、编码和数学等技术任务中表现出色。第三方基准测试显示，DeepSeek-R1在逻辑问题解决、数学计算和代码生成方面的表现优于GPT-4o和其他领先的AI模型。例如，在Codeforces上的得分达到2029 Elo，超过了96.3%的人类参与者。
#
# ## 四、DeepSeek的竞争力分析
#
# ### （一）技术创新
# DeepSeek的核心竞争力在于其技术创新，尤其是MoE架构的应用。这种架构不仅降低了计算成本，还在文本处理任务中保持了高准确性和效率。此外，DeepSeek采用的MHLA技术和FP8混合精度训练也为其带来了显著的优势。
#
# ### （二）性价比
# DeepSeek-V3的训练成本仅为558万美元，相比之下，Meta的Llama-3.1训练成本超过5亿美元。这种低成本的背后，得益于深度求索公司在优化策略上的创新，包括高效的负载均衡、FP8混合精度训练和通信优化等。因此，DeepSeek-V3在保证卓越性能的同时，提供了极低的调用成本，为企业和开发者提供了兼具高性能和经济性的解决方案。
#
# ### （三）开源与社区支持
# DeepSeek采取了开源策略，所有模型均基于MIT许可证授权，可以不受限地用于商业用途。这种开放性不仅提高了透明度，还促进了社区的协作改进，降低了AI技术的采用门槛。开源策略使得DeepSeek成为了那些不愿被锁定在专有生态系统中的企业和独立开发者的理想选择。
#
# ### （四）应用场景拓展
# DeepSeek不仅在通用任务上表现强劲，同时在语言理解、多语言处理和专业场景中也有出色的性能。特别是在中文处理、多任务学习和代码生成等领域，DeepSeek的表现尤为突出。这使得DeepSeek在预算有限情况下的企业和团队中具有吸引力。
#
# ### （五）挑战与不足
# 尽管DeepSeek在多个方面表现出色，但仍存在一些挑战。例如，其上下文窗口长度仅为13万个Token，远低于竞争对手；在某些特定任务上的表现仍有提升空间；此外，作为一家中国公司，DeepSeek必须遵守中国严格的互联网法规，这可能会对其国际市场的扩展产生一定影响。
#
# ## 五、结论
#
# 综上所述，DeepSeek在全球AI大模型竞争中展现出了强大的竞争力。通过技术创新、高性价比、开源策略和应用场景拓展，DeepSeek不仅在性能上与顶级模型相抗衡，还在成本效益上占据明显优势。然而，面对上下文窗口长度、专业领域优化以及生态系统支持等方面的挑战，DeepSeek仍有改进空间。未来，随着技术的不断发展和市场的进一步拓展，DeepSeek有望继续引领AI大模型领域的创新与发展。

# %% [markdown]
# <a href="https://colab.research.google.com/github/mshumer/OpenDeepResearcher/blob/main/open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /opt/anaconda3/lib/python3.12/site-packages (1.6.0)

# %%
import trafilatura
import asyncio
import aiohttp
import json
import time
from collections import deque

TPM_LIMIT = 60  # 每分钟最大请求数
LOCK = asyncio.Lock()  # 异步锁
token_bucket = deque(maxlen=TPM_LIMIT*2)  # 适当扩大缓冲区

# =======================
# Configuration Constants
# =======================
DEEPSEEK_API_KEY = "sk-vvREpHRkCDZlun57ndlOgzWPTu7D4zERHf0tmQ4UIA4tf4SS" # Replace with your DEEPSEEK API key


# Endpoints
#DEEPSEEK_URL = "https://api.siliconflow.cn/v1/chat/completions"
DEEPSEEK_URL = "https://api.lkeap.cloud.tencent.com/v1/chat/completions"

SEARXNG_INSTANCE = "http://localhost:18888"  # 选择一个可用的 SearXNG 实例 参考：https://searx.space/ 或者本地部署：docker run -d --name searxng -p 8888:8080 searxng/searxng

# Default LLM model (can be changed if desired)
#DEFAULT_MODEL = "deepseek-ai/DeepSeek-V3"
DEFAULT_MODEL = "deepseek-v3"

# ============================
# Asynchronous Helper Functions
# ============================

async def call_openrouter_async(session, messages, model=DEFAULT_MODEL):
    global token_bucket
    
    async with LOCK:  # 原子操作开始
        current_time = time.time()
        # 清理过期令牌（1分钟前的请求）
        while token_bucket and token_bucket[0] < current_time - 60:
            token_bucket.popleft()
        
        # 等待直到有可用令牌
        while len(token_bucket) >= TPM_LIMIT:
            oldest = token_bucket[0]
            wait_time = oldest + 60 - current_time
            await asyncio.sleep(max(0, wait_time))
            current_time = time.time()
            # 再次清理过期令牌
            while token_bucket and token_bucket[0] < current_time - 60:
                token_bucket.popleft()
        
        token_bucket.append(current_time)
    
    # API请求逻辑
    headers = {
        "Authorization": f"Bearer {DEEPSEEK_API_KEY}",
        "Content-Type": "application/json"
    }
    payload = {"model": model, "messages": messages}
    
    for retry in range(3):
        try:
            async with session.post(DEEPSEEK_URL, headers=headers, json=payload) as resp:
                if resp.status == 200:
                    result = await resp.json()
                    return result['choices'][0]['message']['content']
                elif resp.status == 429:
                    await asyncio.sleep(2 ** retry)
                    continue
                else:
                    print(f"API Error {resp.status}: {await resp.text()}")
                    return None
        except Exception as e:
            print(f"Request failed: {str(e)}")
            await asyncio.sleep(1)
    
    return None


async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            search_queries = eval(response)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    params = {"q": query, "format": "json"}
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
    }
    try:
        async with session.get(SEARXNG_INSTANCE + "/search", params=params, headers=headers) as resp:
            if resp.status == 200:
                data = await resp.json()
                links = [result["url"] for result in data.get("results", [])]
                return links
            else:
                print(f"SearXNG error: {resp.status}")
                return []
    except Exception as e:
        print("Error performing SearXNG search:", e)
        return []

async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await call_openrouter_async(session, messages)
    return report


async def fetch_webpage_text_async(link):
    """
    使用 trafilatura 异步提取网页主要内容。
    """
    loop = asyncio.get_event_loop()
    downloaded = await loop.run_in_executor(None, trafilatura.fetch_url, link)
    if downloaded:
        text = await loop.run_in_executor(None, trafilatura.extract, downloaded)
        return text
    return None

async def process_link(session, link, user_query, search_query):
    """
    如果链接以 .pdf 或 .xls 结尾，则跳过处理。
    """
    # 检查链接是否以 .pdf 或 .xls 结尾
    if link.lower().endswith(('.pdf', '.xls')):
        print(f"Skipping link as it is a PDF or XLS file: {link}")
        return None

    """
    处理单个链接：获取内容，判断是否有用，并提取相关上下文。
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(link)
    if not page_text:
        print(f"Failed to extract content from: {link}")
        return None

    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")

    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context

    return None

    
# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        print("返回搜索词:", new_search_queries)    
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic:  量化交易的前世今生
# Enter maximum number of iterations (default 10):   3
# 返回搜索词: ['量化交易的历史发展', '量化交易的技术演变', '量化交易的现状与趋势', '量化交易的成功案例分析']
#
# === Iteration 1 ===
# Aggregated 124 unique links from this iteration.
# Fetching content from: https://xueqiu.com/8185159194/277790290
# Fetching content from: https://zhuanlan.zhihu.com/p/146118079
# Fetching content from: https://www.incredibuild.cn/blog/quant-trading-strategies-definitions-and-importance
# Fetching content from: https://xueqiu.com/1160805449/132961443
# Fetching content from: https://www.gelonghui.com/p/253940
# Fetching content from: https://www.investor.org.cn/learning_center/investors_classroom/hot_topic/online/essay_competition_2894/202301/t20230104_627035.shtml
# Fetching content from: https://blog.csdn.net/itcast_cn/article/details/121496459
# Fetching content from: https://www.cnblogs.com/lizhihang/p/12610617.html
# Fetching content from: https://www.bilibili.com/opus/513834399647919696
# Fetching content from: https://zhuanlan.zhihu.com/p/443296363
# Fetching content from: https://zhuanlan.zhihu.com/p/681428318
# Fetching content from: https://xueqiu.com/2964595157/300343599
# Fetching content from: https://baijiahao.baidu.com/s?id=1775986415675514259
# Fetching content from: https://pro.huxiu.com/article/889808.html
# Fetching content from: https://www.zhihu.com/tardis/zm/art/606017818
# Fetching content from: https://www.163.com/money/article/CJU1KC790025817I.html
# Fetching content from: https://zhuanlan.zhihu.com/p/606017818
# Fetching content from: https://finance.sina.com.cn/money/fund/jjzl/2024-02-23/doc-inaiyvxp0999044.shtml
# Fetching content from: https://www.shinnytech.com/blog/tq-quantatitve-transaction/
# Fetching content from: https://cloud.baidu.com/article/2717892
# Fetching content from: https://blog.csdn.net/u012724887/article/details/115180386
# Fetching content from: https://youzhiyouxing.cn/materials/603
# Fetching content from: http://qsyj.ruc.edu.cn/CN/abstract/abstract2261.shtml
# Fetching content from: https://finance.sina.cn/futuremarket/qsyw/2018-01-09/detail-ifyqptqv6549998.d.html
# Fetching content from: https://baike.baidu.com/item/量化交易/5266581
# Fetching content from: https://www.lingjuninvest.com/news/4627
# Fetching content from: http://www.cces.tsinghua.edu.cn/info/1029/1074.htm
# Fetching content from: https://qzc.tsinghua.edu.cn/info/1194/2073.htm
# Fetching content from: https://bigquant.com/wiki/doc/6yep5yyw5lqk5pit5piv5lua5lmip8kgiowqmanwfpemxqoejia-7hUcXKutKq
# Fetching content from: https://support.futunn.com/topic605?lang=zh-cn
# Fetching content from: https://cn.ceibs.edu/article/19480
# Fetching content from: https://36kr.com/p/2656817840980232
# Fetching content from: http://www.cces.tsinghua.edu.cn/qysyjjs/lhlsyj1.htm
# Fetching content from: https://paper.cnstock.com/html/2021-09/08/content_1517799.htm
# Fetching content from: https://www.futunn.com/learn/detail-what-is-algorithmic-trading-53384-220381041
# Fetching content from: https://wiki.mbalib.com/wiki/量化交易
# Fetching content from: https://blog.csdn.net/AlgoPlus/article/details/121886251
# Fetching content from: https://fisf.fudan.edu.cn/ffr/content/17
# Fetching content from: https://www.sohu.com/a/506768836_120362808
# Fetching content from: https://zhuanlan.zhihu.com/p/678978619
# Fetching content from: https://zhuanlan.zhihu.com/p/443300639
# Fetching content from: https://baijiahao.baidu.com/s?id=1777373840517291572
# Fetching content from: https://www.doc88.com/p-31073049086313.html
# Fetching content from: https://blog.csdn.net/QQ3957533237/article/details/144050438
# Fetching content from: https://baijiahao.baidu.com/s?id=1821733047377207345
# Fetching content from: https://bigquant.com/wiki/doc/7hUcXKutKq
# Fetching content from: https://www.dongaigc.com/a/ai-quantitative-trading-exploration
# Fetching content from: http://finance.sina.com.cn/money/future/fmnews/2018-01-09/doc-ifyqptqv6549998.shtml
# Fetching content from: http://www.bilibili.com/read/cv28700809/
# Fetching content from: https://cn.linkedin.com/pulse/%E9%87%8F%E5%8C%96%E6%8A%95%E8%B5%84%E5%8F%91%E5%B1%95%E5%8E%86%E5%8F%B2%E6%B5%85%E6%9E%90-fengxin-dong
# Fetching content from: https://funds.hexun.com/2024-12-12/216129834.html
# Fetching content from: https://heth.ink/Quant4-1/
# Fetching content from: https://www.feishu.cn/content/what-does-quantitative-trading-mean
# Fetching content from: https://bigquant.com/wiki/doc/u7IPZL8JHB
# Fetching content from: https://www.jiqizhixin.com/articles/2019-01-24-3
# Fetching content from: https://www.guandata.com/gy/post/1550.html
# Fetching content from: https://www.cmcmarkets.com/zh/trading-guides/quantitative-trading
# Fetching content from: https://bigquant.com/wiki/doc/kDbDJMANHT
# Fetching content from: https://bigquant.com/wiki/topic/979254c0c1
# Fetching content from: https://finance.sina.com.cn/money/fund/etf/2024-07-01/doc-incatvrn9226039.shtml
# Fetching content from: https://d.wanfangdata.com.cn/thesis/D686477
# Fetching content from: https://blog.csdn.net/alltick01/article/details/142098859
# Fetching content from: https://blog.csdn.net/caiair/article/details/141928211
# Fetching content from: https://bigquant.com/wiki/doc/W9GytZ2Y6E
# Fetching content from: https://www.robeco.com/zh-cn/insights/2024/09/what-the-future-holds-for-quant-investing-ten-hypotheses
# Fetching content from: http://pi.np/guhemow
# Fetching content from: https://zhuanlan.zhihu.com/p/668061445
# Fetching content from: http://gad.gg/hiacari
# Fetching content from: http://jinisi.ni/oveonako
# Fetching content from: https://www.jianshu.com/p/46f12745c95d
# Fetching content from: http://hon.vi/rufot
# Fetching content from: https://blog.csdn.net/sohoqq/article/details/143181206
# Fetching content from: http://foc.cg/hanrisef
# Fetching content from: https://mp.ofweek.com/finance/a656714951537
# Fetching content from: https://japan.icbc.com.cn/icbc/%E7%BD%91%E4%B8%8A%E5%9F%BA%E9%87%91/%E5%9F%BA%E9%87%91%E8%B5%84%E8%AE%AF/%E5%88%86%E6%9E%90%E8%AF%84%E8%AE%BA/%E6%9E%97%E6%88%90%E6%A0%8B%E9%87%8F%E5%8C%96%E6%8A%95%E8%B5%84%E6%98%AF%E5%A4%A7%E6%95%B0%E6%8D%AE%E6%97%B6%E4%BB%A3%E7%9A%84%E5%BF%85%E7%84%B6%E8%B6%8B%E5%8A%BF.htm
# Fetching content from: https://www.stcn.com/article/detail/858608.html
# Fetching content from: https://m.yicai.com/news/102004109.html
# Fetching content from: https://www.cls.cn/detail/846782
# Fetching content from: https://zhuanlan.zhihu.com/p/22179962077
# Fetching content from: http://mikesdod.no/digladu
# Fetching content from: http://su.kn/foejegip
# Fetching content from: http://cogmamhe.hk/un
# Fetching content from: https://zhuanlan.zhihu.com/p/17619950576
# Fetching content from: http://ub.kn/ic
# Fetching content from: https://xueqiu.com/8361164631/117680517
# Fetching content from: http://cuubbok.zm/okikva
# Fetching content from: https://m.kuaiji.com/kuaijishiwu/910688215.html
# Fetching content from: https://www.yanglee.com/research/Details.aspx?i=126083
# Fetching content from: https://m.kuaiji.com/cqf/4240115615.html
# Fetching content from: https://finance.sina.cn/fund/jjgdxw/2024-07-02/detail-incauhff7194154.d.html
# Fetching content from: https://blog.csdn.net/guzhoumingyue/article/details/141531263
# Fetching content from: https://blog.csdn.net/VIP6666666666/article/details/139453211
# Fetching content from: https://zhuanlan.zhihu.com/p/647394840
# Fetching content from: https://blog.csdn.net/weixin_42219751/article/details/101021378
# Fetching content from: https://mirror.xyz/0xE6c5DC16A5B26fbA7eC1f299D5b8fA341f8C3ddc/0rN3V7iPMgNLykFjSugnSWy2A2WtjVLJ_EX1lrXMFZ0
# Fetching content from: https://www.binance.com/zh-CN/square/post/819323
# Fetching content from: http://riwinpu.gy/tuceh
# Fetching content from: https://zhuanlan.zhihu.com/p/378564054
# Fetching content from: http://hakzerli.kr/peisa
# Fetching content from: https://zhuanlan.zhihu.com/p/23364031
# Fetching content from: http://ufadi.nz/wisadwef
# Fetching content from: https://blog.csdn.net/JJLC1019_wx/article/details/138905080
# Fetching content from: http://powu.mw/ureco
# Fetching content from: http://resewefi.mz/rov
# Fetching content from: http://finance.ce.cn/rolling/201602/17/t20160217_8913453.shtml
# Fetching content from: https://finance.sina.cn/2016-02-17/detail-ifxprqea4597202.d.html
# Fetching content from: http://carlingedu.com/news/show-401.html
# Fetching content from: https://aws.amazon.com/cn/blogs/china/amazon-nova-helps-kungfu-trader-unlock-intelligent-quantitative-analysis/
# Fetching content from: https://www.beaconsi.org/mm-notes/3360-%E9%87%8F%E5%8C%96%E4%BA%A4%E6%98%93%E8%80%85thomas-%E9%9D%A2%E4%B8%B4%E7%9A%84%E6%8C%91%E6%88%98.html
# Fetching content from: http://us.yt/nenufov
# Fetching content from: https://zhuanlan.zhihu.com/p/378862243
# Fetching content from: http://hu.cn/owzu
# Fetching content from: https://wenku.baidu.com/view/3f02fe780440be1e650e52ea551810a6f524c82f.html
# Fetching content from: http://tij.gh/pu
# Fetching content from: https://www.zhiguf.com/focusnews_detail/1241152
# Fetching content from: http://icaledlu.ly/bid
# Fetching content from: https://www.msn.cn/zh-cn/news/other/%E9%87%8F%E5%8C%96%E6%8A%95%E8%B5%84%E7%AD%96%E7%95%A5%E7%9A%84%E6%A1%88%E4%BE%8B%E5%88%86%E6%9E%90-%E5%88%86%E6%9E%90%E6%88%90%E5%8A%9F%E7%9A%84%E9%87%8F%E5%8C%96%E6%8A%95%E8%B5%84%E7%AD%96%E7%95%A5%E6%A1%88%E4%BE%8B/ar-BB1lxBum
# Fetching content from: http://pi.br/pana
# Fetching content from: https://blog.alltick.co/quant-legend/
# Fetching content from: https://quant.10jqka.com.cn/view/article/1586
# Fetching content from: https://www.gaodun.com/cqf/1530020.html
# Fetching content from: https://36kr.com/p/2660913816789767
# Fetching content from: https://www.36kr.com/p/2414732392473352
# Fetching content from: https://www.36kr.com/p/2230514870211718
# Failed to extract content from: https://zhuanlan.zhihu.com/p/146118079
# Failed to extract content from: https://zhuanlan.zhihu.com/p/443296363
# Failed to extract content from: https://zhuanlan.zhihu.com/p/681428318
# Failed to extract content from: https://zhuanlan.zhihu.com/p/606017818
# Failed to extract content from: https://cn.ceibs.edu/article/19480
# Failed to extract content from: https://zhuanlan.zhihu.com/p/678978619
# Failed to extract content from: https://zhuanlan.zhihu.com/p/443300639
# Failed to extract content from: https://zhuanlan.zhihu.com/p/668061445
# Failed to extract content from: https://cn.linkedin.com/pulse/%E9%87%8F%E5%8C%96%E6%8A%95%E8%B5%84%E5%8F%91%E5%B1%95%E5%8E%86%E5%8F%B2%E6%B5%85%E6%9E%90-fengxin-dong
# Failed to extract content from: http://jinisi.ni/oveonako
# Failed to extract content from: http://hon.vi/rufot
# Failed to extract content from: http://foc.cg/hanrisef
# Failed to extract content from: http://mikesdod.no/digladu
# Failed to extract content from: https://zhuanlan.zhihu.com/p/22179962077
# Failed to extract content from: http://cogmamhe.hk/un
# Failed to extract content from: https://zhuanlan.zhihu.com/p/17619950576
# Failed to extract content from: http://su.kn/foejegip
# Failed to extract content from: https://www.yanglee.com/research/Details.aspx?i=126083
# Failed to extract content from: http://ub.kn/ic
# Failed to extract content from: http://gad.gg/hiacari
# Failed to extract content from: http://pi.np/guhemow
# Failed to extract content from: https://zhuanlan.zhihu.com/p/647394840
# Failed to extract content from: https://www.binance.com/zh-CN/square/post/819323
# Failed to extract content from: https://zhuanlan.zhihu.com/p/378564054
# Failed to extract content from: https://zhuanlan.zhihu.com/p/23364031
# Failed to extract content from: http://cuubbok.zm/okikva
# Failed to extract content from: http://riwinpu.gy/tuceh
# Failed to extract content from: https://mirror.xyz/0xE6c5DC16A5B26fbA7eC1f299D5b8fA341f8C3ddc/0rN3V7iPMgNLykFjSugnSWy2A2WtjVLJ_EX1lrXMFZ0
# Failed to extract content from: https://zhuanlan.zhihu.com/p/378862243
# Failed to extract content from: http://hu.cn/owzu
# Failed to extract content from: http://tij.gh/pu
# Failed to extract content from: http://hakzerli.kr/peisa
# Failed to extract content from: http://ufadi.nz/wisadwef
# Failed to extract content from: http://us.yt/nenufov
# Failed to extract content from: https://www.bilibili.com/opus/513834399647919696
# Failed to extract content from: https://36kr.com/p/2656817840980232
# Failed to extract content from: http://www.bilibili.com/read/cv28700809/
# Failed to extract content from: http://resewefi.mz/rov
# Failed to extract content from: http://powu.mw/ureco
# Failed to extract content from: https://www.msn.cn/zh-cn/news/other/%E9%87%8F%E5%8C%96%E6%8A%95%E8%B5%84%E7%AD%96%E7%95%A5%E7%9A%84%E6%A1%88%E4%BE%8B%E5%88%86%E6%9E%90-%E5%88%86%E6%9E%90%E6%88%90%E5%8A%9F%E7%9A%84%E9%87%8F%E5%8C%96%E6%8A%95%E8%B5%84%E7%AD%96%E7%95%A5%E6%A1%88%E4%BE%8B/ar-BB1lxBum
# Failed to extract content from: https://36kr.com/p/2660913816789767
# Failed to extract content from: https://www.36kr.com/p/2230514870211718
# Failed to extract content from: https://www.36kr.com/p/2414732392473352
# Failed to extract content from: http://pi.br/pana
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Failed to extract content from: http://icaledlu.ly/bid
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Page usefulness for https://www.cnblogs.com/lizhihang/p/12610617.html: Yes
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Page usefulness for https://xueqiu.com/8185159194/277790290: No
# Page usefulness for https://xueqiu.com/2964595157/300343599: No
# Page usefulness for https://baijiahao.baidu.com/s?id=1775986415675514259: No
# Page usefulness for https://blog.csdn.net/itcast_cn/article/details/121496459: No
# Page usefulness for https://wiki.mbalib.com/wiki/量化交易: No
# Page usefulness for https://www.zhihu.com/tardis/zm/art/606017818: No
# Page usefulness for https://www.shinnytech.com/blog/tq-quantatitve-transaction/: No
# Page usefulness for https://baijiahao.baidu.com/s?id=1777373840517291572: No
# Page usefulness for https://www.futunn.com/learn/detail-what-is-algorithmic-trading-53384-220381041: No
# Page usefulness for https://www.gelonghui.com/p/253940: No
# Page usefulness for https://blog.csdn.net/alltick01/article/details/142098859: No
# Page usefulness for https://baike.baidu.com/item/量化交易/5266581: No
# Page usefulness for https://finance.sina.cn/futuremarket/qsyw/2018-01-09/detail-ifyqptqv6549998.d.html: No
# Page usefulness for https://finance.sina.com.cn/money/fund/etf/2024-07-01/doc-incatvrn9226039.shtml: No
# Page usefulness for https://xueqiu.com/1160805449/132961443: No
# Page usefulness for https://blog.csdn.net/sohoqq/article/details/143181206: No
# Page usefulness for https://youzhiyouxing.cn/materials/603: No
# Page usefulness for https://m.yicai.com/news/102004109.html: No
# Page usefulness for https://www.dongaigc.com/a/ai-quantitative-trading-exploration: No
# Page usefulness for https://www.sohu.com/a/506768836_120362808: No
# Page usefulness for https://bigquant.com/wiki/doc/kDbDJMANHT: No
# Page usefulness for https://fisf.fudan.edu.cn/ffr/content/17: No
# Page usefulness for https://pro.huxiu.com/article/889808.html: No
# Page usefulness for https://d.wanfangdata.com.cn/thesis/D686477: No
# Page usefulness for http://www.cces.tsinghua.edu.cn/qysyjjs/lhlsyj1.htm: No
# Page usefulness for https://www.jianshu.com/p/46f12745c95d: No
# Page usefulness for https://blog.csdn.net/caiair/article/details/141928211: No
# Page usefulness for https://blog.csdn.net/u012724887/article/details/115180386: No
# Page usefulness for http://qsyj.ruc.edu.cn/CN/abstract/abstract2261.shtml: No
# Page usefulness for https://www.doc88.com/p-31073049086313.html: No
# Page usefulness for https://baijiahao.baidu.com/s?id=1821733047377207345: No
# Page usefulness for https://blog.csdn.net/QQ3957533237/article/details/144050438: No
# Page usefulness for https://bigquant.com/wiki/doc/u7IPZL8JHB: No
# Page usefulness for https://xueqiu.com/8361164631/117680517: No
# Page usefulness for https://www.lingjuninvest.com/news/4627: No
# Page usefulness for https://finance.sina.com.cn/money/fund/jjzl/2024-02-23/doc-inaiyvxp0999044.shtml: No
# Page usefulness for https://finance.sina.cn/fund/jjgdxw/2024-07-02/detail-incauhff7194154.d.html: No
# Page usefulness for https://japan.icbc.com.cn/icbc/%E7%BD%91%E4%B8%8A%E5%9F%BA%E9%87%91/%E5%9F%BA%E9%87%91%E8%B5%84%E8%AE%AF/%E5%88%86%E6%9E%90%E8%AF%84%E8%AE%BA/%E6%9E%97%E6%88%90%E6%A0%8B%E9%87%8F%E5%8C%96%E6%8A%95%E8%B5%84%E6%98%AF%E5%A4%A7%E6%95%B0%E6%8D%AE%E6%97%B6%E4%BB%A3%E7%9A%84%E5%BF%85%E7%84%B6%E8%B6%8B%E5%8A%BF.htm: No
# Page usefulness for https://funds.hexun.com/2024-12-12/216129834.html: No
# Page usefulness for https://cloud.baidu.com/article/2717892: No
# Page usefulness for https://bigquant.com/wiki/doc/W9GytZ2Y6E: No
# Page usefulness for https://www.guandata.com/gy/post/1550.html: No
# Page usefulness for https://www.cls.cn/detail/846782: No
# Page usefulness for https://www.robeco.com/zh-cn/insights/2024/09/what-the-future-holds-for-quant-investing-ten-hypotheses: No
# Page usefulness for https://bigquant.com/wiki/topic/979254c0c1: No
# Page usefulness for https://www.feishu.cn/content/what-does-quantitative-trading-mean: No
# Page usefulness for https://blog.csdn.net/AlgoPlus/article/details/121886251: No
# Page usefulness for https://www.163.com/money/article/CJU1KC790025817I.html: No
# Page usefulness for https://bigquant.com/wiki/doc/6yep5yyw5lqk5pit5piv5lua5lmip8kgiowqmanwfpemxqoejia-7hUcXKutKq: No
# Page usefulness for https://www.stcn.com/article/detail/858608.html: No
# Page usefulness for http://finance.sina.com.cn/money/future/fmnews/2018-01-09/doc-ifyqptqv6549998.shtml: No
# Page usefulness for https://www.incredibuild.cn/blog/quant-trading-strategies-definitions-and-importance: No
# Page usefulness for https://heth.ink/Quant4-1/: No
# Page usefulness for https://bigquant.com/wiki/doc/7hUcXKutKq: No
# Page usefulness for https://mp.ofweek.com/finance/a656714951537: No
# Page usefulness for http://www.cces.tsinghua.edu.cn/info/1029/1074.htm: No
# Page usefulness for https://paper.cnstock.com/html/2021-09/08/content_1517799.htm: Yes
# Page usefulness for https://www.investor.org.cn/learning_center/investors_classroom/hot_topic/online/essay_competition_2894/202301/t20230104_627035.shtml: No
# Failed to extract content from: https://www.cmcmarkets.com/zh/trading-guides/quantitative-trading
# Page usefulness for https://www.jiqizhixin.com/articles/2019-01-24-3: Yes
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Page usefulness for https://qzc.tsinghua.edu.cn/info/1194/2073.htm: No
# Page usefulness for https://m.kuaiji.com/kuaijishiwu/910688215.html: No
# Page usefulness for https://wenku.baidu.com/view/3f02fe780440be1e650e52ea551810a6f524c82f.html: No
# Page usefulness for https://www.zhiguf.com/focusnews_detail/1241152: No
# Page usefulness for https://blog.csdn.net/weixin_42219751/article/details/101021378: No
# Page usefulness for https://quant.10jqka.com.cn/view/article/1586: No
# Page usefulness for https://finance.sina.cn/2016-02-17/detail-ifxprqea4597202.d.html: No
# Page usefulness for http://finance.ce.cn/rolling/201602/17/t20160217_8913453.shtml: No
# Page usefulness for https://m.kuaiji.com/cqf/4240115615.html: No
# Page usefulness for https://aws.amazon.com/cn/blogs/china/amazon-nova-helps-kungfu-trader-unlock-intelligent-quantitative-analysis/: No
# Page usefulness for https://blog.csdn.net/VIP6666666666/article/details/139453211: No
# Page usefulness for https://www.gaodun.com/cqf/1530020.html: No
# Page usefulness for http://carlingedu.com/news/show-401.html: No
# Page usefulness for https://www.beaconsi.org/mm-notes/3360-%E9%87%8F%E5%8C%96%E4%BA%A4%E6%98%93%E8%80%85thomas-%E9%9D%A2%E4%B8%B4%E7%9A%84%E6%8C%91%E6%88%98.html: No
# Page usefulness for https://blog.csdn.net/JJLC1019_wx/article/details/138905080: No
# Page usefulness for https://blog.alltick.co/quant-legend/: No
# Page usefulness for https://support.futunn.com/topic605?lang=zh-cn: No
# Page usefulness for https://blog.csdn.net/guzhoumingyue/article/details/141531263: Yes
# Extracted context from https://blog.csdn.net/guzhoumingyue/article/details/141531263 (first 200 chars): 量化交易（Quantitative Trading）是一种利用数学模型和计算机算法进行金融市场交易的策略。它通常依赖于大量的数据分析，以识别潜在的交易机会并制定买卖决策。量化交易的核心是运用统计学、数学建模和计算机科学等技术，通过数据驱动的方法来实现投资回报。
#
# 量化交易的基本要素包括数据收集、数据分析、策略制定和执行交易。数据收集涉及获取历史和实时市场数据，如价格、成交量、财务报表等。数据分析使
# LLM provided new search queries: ['量化交易的起源与早期发展', '量化交易在不同市场的应用', '量化交易的风险管理策略', '量化交易的未来技术趋势']
#
# === Iteration 2 ===
# Aggregated 140 unique links from this iteration.
# Fetching content from: https://zhuanlan.zhihu.com/p/443296363
# Fetching content from: https://finance.sina.cn/futuremarket/qsyw/2018-01-09/detail-ifyqptqv6549998.d.html
# Fetching content from: https://xueqiu.com/1160805449/132961443
# Fetching content from: http://finance.sina.com.cn/money/future/fmnews/2018-01-09/doc-ifyqptqv6549998.shtml
# Fetching content from: https://cloud.baidu.com/article/2717892
# Fetching content from: https://blog.csdn.net/u012724887/article/details/115180386
# Fetching content from: https://www.vzkoo.com/question/1719822269573320
# Fetching content from: https://m.gelonghui.com/p/637150
# Fetching content from: https://www.taifex.com.tw/file/taifex/CHINESE/10/eBooks/202112/17/
# Fetching content from: https://xueqiu.com/8185159194/277790290
# Fetching content from: https://xueqiu.com/2964595157/300343599
# Fetching content from: https://zhuanlan.zhihu.com/p/681428318
# Fetching content from: https://zhuanlan.zhihu.com/p/268058169
# Fetching content from: https://baijiahao.baidu.com/s?id=1775986415675514259
# Fetching content from: https://www.sohu.com/a/350142559_757677
# Fetching content from: https://www.zhihu.com/tardis/zm/art/606017818
# Fetching content from: https://www.sohu.com/a/238037861_100195237
# Fetching content from: https://www.futures.org.tw/file/attachmentStatic/4028829e6c18c627016c1c90dd1f005f
# Fetching content from: https://www.feishu.cn/content/what-does-quantitative-trading-mean
# Fetching content from: https://support.futunn.com/topic605?lang=zh-cn
# Fetching content from: https://fisf.fudan.edu.cn/ffr/content/17
# Fetching content from: https://futures.hexun.com/2024-08-17/214038103.html
# Fetching content from: https://finance.sina.cn/sa/2014-03-30/detail-ikkntiam8281303.d.html
# Fetching content from: https://futures.hexun.com/2024-10-05/214835299.html
# Fetching content from: https://cn.ceibs.edu/article/19480
# Fetching content from: https://blog.csdn.net/BGoodHabit/article/details/138673151
# Fetching content from: https://www.investor.org.cn/learning_center/investors_classroom/hot_topic/online/essay_competition_2894/202301/t20230104_627035.shtml
# Fetching content from: https://www.zhihu.com/question/641158836
# Fetching content from: http://povudbos.me/wem
# Fetching content from: https://xueqiu.com/2536633012/298103955
# Fetching content from: http://ale.cz/tapeuru
# Fetching content from: https://xueqiu.com/8580063515/270816355
# Fetching content from: http://vog.co.uk/bir
# Fetching content from: https://xueqiu.com/4203312072/298255560
# Fetching content from: http://vocesav.cz/jebko
# Fetching content from: https://zhuanlan.zhihu.com/p/59722636
# Fetching content from: https://blog.csdn.net/2401_85338387/article/details/140553183
# Fetching content from: https://bigquant.com/wiki/doc/7hUcXKutKq
# Fetching content from: https://maimai.cn/article/detail?fid=1834986079&efid=o-bx8-3JZn-gVIoYharMGA
# Fetching content from: https://time.geekbang.org/column/article/410443
# Fetching content from: https://zhuanlan.zhihu.com/p/697502567
# Fetching content from: https://qzc.tsinghua.edu.cn/info/1194/2073.htm
# Fetching content from: https://www.robeco.com/zh-cn/insights/2023/07/next-gen-quant-evolution-using-new-signals-in-existing-strategies
# Fetching content from: https://finance.sina.com.cn/money/fund/jjzl/2024-02-23/doc-inaiyvxp0999044.shtml
# Fetching content from: https://cloud.baidu.com/article/2717766
# Fetching content from: http://sas.fo/handebwap
# Fetching content from: https://www.zhihu.com/question/583935098
# Fetching content from: http://sodebadup.org/fanu
# Fetching content from: https://finance.sina.com.cn/zl/stock/20140330/111818657542.shtml
# Fetching content from: http://lek.lb/envufmi
# Fetching content from: https://www.zhihu.com/market/pub/119943833/manuscript/1283922108435841024
# Fetching content from: http://rocbawpal.ht/bif
# Fetching content from: https://www.cmcmarkets.com/zh/trading-guides/quantitative-trading
# Fetching content from: http://ute.eh/gabte
# Fetching content from: https://www.incredibuild.cn/blog/quant-trading-strategies-definitions-and-importance
# Fetching content from: https://finance.sina.com.cn/money/smjj/2024-07-17/doc-incemuhy9642131.shtml
# Fetching content from: https://emt.18.cn/article/article-info/2
# Fetching content from: https://quant.10jqka.com.cn/view/article/1586
# Fetching content from: https://www.jinse.cn/blockchain/761916.html
# Fetching content from: https://d.wanfangdata.com.cn/thesis/D686477
# Fetching content from: https://www.guandata.com/gy/post/1550.html
# Fetching content from: https://paper.cnstock.com/html/2021-09/08/content_1517799.htm
# Fetching content from: https://funds.hexun.com/2024-12-12/216129834.html
# Fetching content from: https://heth.ink/Quant4-1/
# Fetching content from: http://avehbo.bf/amivu
# Fetching content from: https://www.zhihu.com/question/485507667
# Fetching content from: https://www.finlab.tw/%E9%87%8F%E5%8C%96%E4%BA%A4%E6%98%93%E5%AE%8C%E6%95%B4%E6%8C%87%E5%8D%97%EF%BC%9A%E7%AD%96%E7%95%A5%E3%80%81%E5%AF%A6%E6%96%BD%E8%88%87%E9%A2%A8%E9%9A%AA%E7%AE%A1%E7%90%86/
# Fetching content from: https://www.stcn.com/article/detail/1398879.html
# Fetching content from: https://zhuanlan.zhihu.com/p/542011531
# Fetching content from: http://www.sanhsin.edu.tw/video/%E9%87%8F%E5%8C%96%E4%BA%A4%E6%98%93%E5%9C%A8%E9%A0%90%E6%B8%AC%E4%B8%AD%E7%9A%84%E6%87%89%E7%94%A8#!
# Fetching content from: https://www.sohu.com/a/234708302_769402
# Fetching content from: https://www.qchaos.com/quantum_academy/basic_knowledge/6619/
# Fetching content from: http://hepepa.ec/cuvjifheh
# Fetching content from: https://zhuanlan.zhihu.com/p/106837713
# Fetching content from: http://emuhuv.va/ewejo
# Fetching content from: https://zhuanlan.zhihu.com/p/678211416
# Fetching content from: http://so.gf/rivut
# Fetching content from: https://app-web.chnfund.com/YHHEediting/202401/t20240102_4309780.html
# Fetching content from: http://si.bb/pilieru
# Fetching content from: https://zhuanlan.zhihu.com/p/661592567
# Fetching content from: https://www.tejwin.com/insight/quantitative-trading/
# Fetching content from: https://mp.weixin.qq.com/s/hfJ3d5oSc-foF5HOF1sGPQ
# Fetching content from: https://bigquant.com/wiki/topic/e191231ef9
# Fetching content from: https://bigquant.com/wiki/doc/5bi46keb6yep5yyw5oqv6lwe562w55wl-kDbDJMANHT
# Fetching content from: https://goodjob.nkust.edu.tw/app/%E9%87%8F%E5%8C%96%E4%BA%A4%E6%98%93%E5%9C%A8%E9%A0%90%E6%B8%AC%E4%B8%AD%E7%9A%84%E6%87%89%E7%94%A8#!
# Fetching content from: https://www.compassedu.hk/post_28874
# Fetching content from: https://www.gaodun.com/cqf/1530020.html
# Fetching content from: https://funds.hexun.com/2025-01-22/216979003.html
# Fetching content from: http://nowmamme.ml/vaotfen
# Skipping link as it is a PDF or XLS file: https://www.investor.org.cn/learning_center/gmjytx/bk/kj/202302/P020230228422544808750.pdf
# Fetching content from: http://ru.pm/ba
# Fetching content from: https://blog.csdn.net/JJLC1019_wx/article/details/138905080
# Fetching content from: http://ub.ga/toge
# Fetching content from: https://xueqiu.com/1347292196/317038610
# Fetching content from: http://inva.ke/soccuze
# Fetching content from: https://www.qchaos.com/quantum_academy/basic_knowledge/8810/
# Fetching content from: http://fiketra.pw/acivoro
# Fetching content from: https://www.callcar.com.tw/app/%E9%87%8F%E5%8C%96%E6%8A%95%E8%B3%87%E7%AD%96%E7%95%A5
# Fetching content from: https://zhuanlan.zhihu.com/p/626090485
# Fetching content from: https://www.myquant.cn/docs/guide/672
# Fetching content from: https://bigquant.com/wiki/topic/e31be055f0
# Fetching content from: https://m.gelonghui.com/p/29999
# Fetching content from: https://bigquant.com/wiki/doc/u7IPZL8JHB
# Fetching content from: https://www.zhihu.com/question/24179101/answers/updated
# Fetching content from: https://blog.csdn.net/guzhoumingyue/article/details/141531263
# Fetching content from: https://cj.sina.com.cn/articles/view/6314832590/17864b2ce00101227s
# Fetching content from: http://zaati.tg/nudaha
# Fetching content from: https://bigquant.com/wiki/doc/UiOpLEXee4
# Fetching content from: https://blog.csdn.net/u010225915/article/details/144513725
# Fetching content from: https://36kr.com/p/2333434592872072
# Fetching content from: https://www.robeco.com/zh-cn/insights/2024/09/what-the-future-holds-for-quant-investing-ten-hypotheses
# Fetching content from: https://blog.csdn.net/alltick01/article/details/142098859
# Fetching content from: https://www.gaodun.com/cqf/1468657.html
# Fetching content from: https://zhuanlan.zhihu.com/p/649778564
# Fetching content from: https://bigquant.com/wiki/doc/2023-u7IPZL8JHB
# Fetching content from: https://www.jianshu.com/p/46f12745c95d
# Fetching content from: https://xueqiu.com/8831968704/214506962
# Fetching content from: https://zhuanlan.zhihu.com/p/38585757
# Fetching content from: https://blog.csdn.net/Q3957533237/article/details/144081787
# Fetching content from: https://blog.csdn.net/caiair/article/details/141928211
# Fetching content from: https://baijiahao.baidu.com/s?id=1792405361925329892
# Fetching content from: https://www.qchaos.com/quantum_academy/basic_knowledge/6542/
# Fetching content from: https://www.oryoy.com/news/jie-ma-liang-hua-jiao-yi-jie-mi-suan-fa-zai-jin-rong-shi-chang-zhong-de-ying-yong-yu-tiao-zhan.html
# Fetching content from: https://blog.csdn.net/2401_85528116/article/details/139930336
# Fetching content from: https://finance.sina.com.cn/money/fund/etf/2024-07-01/doc-incatvrn9226039.shtml
# Fetching content from: https://cloud.baidu.com/article/3350334
# Fetching content from: https://cloud.baidu.com/article/3276311
# Fetching content from: https://mirror.xyz/0xe2c14aCD84F7ABdFd175843fFc2F78Dba4fC5E6D/-8crCiRFDiG8JtpAi7rgwRsqxX_VWw7DJDK8QD9pAGo
# Fetching content from: https://www.36kr.com/p/2586941767755393
# Fetching content from: http://www.jzlh999.com/index.php?m=home&c=View&a=index&aid=68&uiset=on&v=pc
# Fetching content from: http://side.cuhk.edu.cn/zh-hans/article/914
# Fetching content from: https://www2.deloitte.com/cn/zh/pages/technology/articles/tech-trends-2024.html
# Fetching content from: https://www.haotouxt.com/article/3026
# Fetching content from: https://bigquant.com/wiki/collection/5lit6aky5oql5zgk-dLopDVBB53
# Fetching content from: https://zhuanlan.zhihu.com/p/66885908
# Fetching content from: https://www.jiqizhixin.com/articles/2019-01-24-3
# Fetching content from: https://m.yicai.com/news/102004109.html
# Fetching content from: https://36kr.com/p/2042367608704265
# Fetching content from: https://finance.sina.cn/fund/jjgdxw/2024-07-02/detail-incauhff7194154.d.html
# Fetching content from: https://www.36kr.com/p/2230514870211718
# Failed to extract content from: https://zhuanlan.zhihu.com/p/443296363
# Failed to extract content from: https://zhuanlan.zhihu.com/p/268058169
# Failed to extract content from: https://zhuanlan.zhihu.com/p/681428318
# Failed to extract content from: https://cn.ceibs.edu/article/19480
# Failed to extract content from: https://www.zhihu.com/question/641158836
# Failed to extract content from: https://zhuanlan.zhihu.com/p/59722636
# Failed to extract content from: http://vocesav.cz/jebko
# Failed to extract content from: https://zhuanlan.zhihu.com/p/697502567
# Failed to extract content from: https://maimai.cn/article/detail?fid=1834986079&efid=o-bx8-3JZn-gVIoYharMGA
# Failed to extract content from: https://www.zhihu.com/question/583935098
# Failed to extract content from: http://sodebadup.org/fanu
# Failed to extract content from: http://lek.lb/envufmi
# Failed to extract content from: http://ale.cz/tapeuru
# Failed to extract content from: http://sas.fo/handebwap
# Failed to extract content from: https://www.zhihu.com/question/485507667
# Failed to extract content from: https://zhuanlan.zhihu.com/p/542011531
# Failed to extract content from: https://zhuanlan.zhihu.com/p/106837713
# Failed to extract content from: https://zhuanlan.zhihu.com/p/678211416
# Failed to extract content from: http://so.gf/rivut
# Failed to extract content from: http://avehbo.bf/amivu
# Failed to extract content from: https://zhuanlan.zhihu.com/p/661592567
# Failed to extract content from: http://emuhuv.va/ewejo
# Failed to extract content from: http://nowmamme.ml/vaotfen
# Failed to extract content from: http://hepepa.ec/cuvjifheh
# Failed to extract content from: http://ute.eh/gabte
# Failed to extract content from: http://povudbos.me/wem
# Failed to extract content from: http://fiketra.pw/acivoro
# Failed to extract content from: http://rocbawpal.ht/bif
# Failed to extract content from: http://ub.ga/toge
# Failed to extract content from: https://zhuanlan.zhihu.com/p/626090485
# Failed to extract content from: https://www.zhihu.com/question/24179101/answers/updated
# Failed to extract content from: http://ru.pm/ba
# Failed to extract content from: http://si.bb/pilieru
# Failed to extract content from: http://www.sanhsin.edu.tw/video/%E9%87%8F%E5%8C%96%E4%BA%A4%E6%98%93%E5%9C%A8%E9%A0%90%E6%B8%AC%E4%B8%AD%E7%9A%84%E6%87%89%E7%94%A8#!
# Failed to extract content from: https://zhuanlan.zhihu.com/p/649778564
# Failed to extract content from: https://zhuanlan.zhihu.com/p/38585757
# Failed to extract content from: http://zaati.tg/nudaha
# Failed to extract content from: http://inva.ke/soccuze
# Failed to extract content from: https://mirror.xyz/0xe2c14aCD84F7ABdFd175843fFc2F78Dba4fC5E6D/-8crCiRFDiG8JtpAi7rgwRsqxX_VWw7DJDK8QD9pAGo
# Failed to extract content from: https://zhuanlan.zhihu.com/p/66885908
# Failed to extract content from: https://time.geekbang.org/column/article/410443
# Failed to extract content from: https://www.futures.org.tw/file/attachmentStatic/4028829e6c18c627016c1c90dd1f005f
# Failed to extract content from: http://side.cuhk.edu.cn/zh-hans/article/914
# Failed to extract content from: https://emt.18.cn/article/article-info/2
# Failed to extract content from: http://vog.co.uk/bir
# Failed to extract content from: https://36kr.com/p/2333434592872072
# Failed to extract content from: https://www.36kr.com/p/2586941767755393
# Failed to extract content from: https://36kr.com/p/2042367608704265
# Failed to extract content from: https://www.36kr.com/p/2230514870211718
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Failed to extract content from: https://www.taifex.com.tw/file/taifex/CHINESE/10/eBooks/202112/17/
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Failed to extract content from: https://www.cmcmarkets.com/zh/trading-guides/quantitative-trading
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Page usefulness for http://finance.sina.com.cn/money/future/fmnews/2018-01-09/doc-ifyqptqv6549998.shtml: Yes
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Page usefulness for https://xueqiu.com/1347292196/317038610: Yes
# Page usefulness for https://cloud.baidu.com/article/2717892: No
# Page usefulness for https://finance.sina.cn/sa/2014-03-30/detail-ikkntiam8281303.d.html: No
# Failed to extract content from: https://goodjob.nkust.edu.tw/app/%E9%87%8F%E5%8C%96%E4%BA%A4%E6%98%93%E5%9C%A8%E9%A0%90%E6%B8%AC%E4%B8%AD%E7%9A%84%E6%87%89%E7%94%A8#!
# Page usefulness for https://www.investor.org.cn/learning_center/investors_classroom/hot_topic/online/essay_competition_2894/202301/t20230104_627035.shtml: No
# Failed to extract content from: https://www.callcar.com.tw/app/%E9%87%8F%E5%8C%96%E6%8A%95%E8%B3%87%E7%AD%96%E7%95%A5
# Page usefulness for https://blog.csdn.net/BGoodHabit/article/details/138673151: No
# Page usefulness for https://www.finlab.tw/%E9%87%8F%E5%8C%96%E4%BA%A4%E6%98%93%E5%AE%8C%E6%95%B4%E6%8C%87%E5%8D%97%EF%BC%9A%E7%AD%96%E7%95%A5%E3%80%81%E5%AF%A6%E6%96%BD%E8%88%87%E9%A2%A8%E9%9A%AA%E7%AE%A1%E7%90%86/: No
# Page usefulness for https://support.futunn.com/topic605?lang=zh-cn: No
# Page usefulness for https://www.jinse.cn/blockchain/761916.html: No
# Page usefulness for https://xueqiu.com/8580063515/270816355: No
# Page usefulness for https://qzc.tsinghua.edu.cn/info/1194/2073.htm: No
# Page usefulness for https://futures.hexun.com/2024-08-17/214038103.html: No
# Page usefulness for https://cloud.baidu.com/article/2717766: No
# Page usefulness for https://xueqiu.com/8185159194/277790290: No
# Page usefulness for https://m.gelonghui.com/p/637150: No
# Page usefulness for https://www.stcn.com/article/detail/1398879.html: No
# Failed to extract content from: https://www.compassedu.hk/post_28874
# Page usefulness for https://d.wanfangdata.com.cn/thesis/D686477: No
# Page usefulness for https://blog.csdn.net/2401_85338387/article/details/140553183: No
# Page usefulness for https://app-web.chnfund.com/YHHEediting/202401/t20240102_4309780.html: No
# Page usefulness for https://xueqiu.com/2536633012/298103955: No
# Page usefulness for https://baijiahao.baidu.com/s?id=1775986415675514259: No
# Page usefulness for https://www.guandata.com/gy/post/1550.html: No
# Page usefulness for https://futures.hexun.com/2024-10-05/214835299.html: No
# Page usefulness for https://bigquant.com/wiki/doc/UiOpLEXee4: No
# Page usefulness for https://www.zhihu.com/tardis/zm/art/606017818: No
# Page usefulness for https://www.qchaos.com/quantum_academy/basic_knowledge/8810/: No
# Page usefulness for https://www.gaodun.com/cqf/1530020.html: No
# Page usefulness for https://funds.hexun.com/2025-01-22/216979003.html: No
# Page usefulness for https://www.sohu.com/a/234708302_769402: No
# Page usefulness for https://blog.csdn.net/guzhoumingyue/article/details/141531263: No
# Page usefulness for https://bigquant.com/wiki/doc/u7IPZL8JHB: No
# Page usefulness for https://m.gelonghui.com/p/29999: No
# Page usefulness for https://www.sohu.com/a/238037861_100195237: No
# Page usefulness for https://xueqiu.com/1160805449/132961443: No
# Page usefulness for https://paper.cnstock.com/html/2021-09/08/content_1517799.htm: No
# Page usefulness for https://finance.sina.cn/futuremarket/qsyw/2018-01-09/detail-ifyqptqv6549998.d.html: No
# Page usefulness for https://www.sohu.com/a/350142559_757677: No
# Page usefulness for https://bigquant.com/wiki/topic/e31be055f0: No
# Page usefulness for https://www.vzkoo.com/question/1719822269573320: No
# Page usefulness for https://finance.sina.com.cn/zl/stock/20140330/111818657542.shtml: No
# Page usefulness for https://xueqiu.com/4203312072/298255560: No
# ...
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Page usefulness for https://www.stcn.com/article/detail/1124642.html: Yes
# Request failed: 'choices'
# Page usefulness for https://blog.csdn.net/sohoqq/article/details/143181206: No
# Page usefulness for https://blog.csdn.net/caiair/article/details/141928211: No
# Request failed: 'choices'
# Page usefulness for https://www.icbc.com.cn/page/721852476184887318.html: No
# Page usefulness for https://www.jiqizhixin.com/articles/2019-01-24-3: No
# Page usefulness for https://bigquant.com/: No
# Page usefulness for https://cloud.baidu.com/article/3350334: No
# Page usefulness for https://wiki.mbalib.com/wiki/量化交易: No
# Page usefulness for https://jrj.sh.gov.cn/HJJS195/20240416/dc204f29587f44518b698335004dcd73.html: No
# Page usefulness for http://www.news.cn/2023-09/04/c_1212263498.htm: No
# Page usefulness for https://finance.sina.com.cn/roll/2024-02-22/doc-inaiwsym8967475.shtml: No
# Page usefulness for https://baijiahao.baidu.com/s?id=1823025213501019305: No
# Page usefulness for https://finance.sina.com.cn/money/smjj/smdt/2024-04-15/doc-inarxkxn6671759.shtml: No
# Page usefulness for https://www.gtja.com/cos/look/detail/765459292679828.html: No
# Page usefulness for https://www.investor.org.cn/learning_center/investors_classroom/hot_topic/online/essay_competition_2894/202301/t20230104_627035.shtml: No
# Page usefulness for https://new.qq.com/rain/a/20230911A086QZ00: No
# Page usefulness for https://finance.sina.com.cn/stock/marketresearch/2024-02-21/doc-inaitxcr0772543.shtml: No
# Page usefulness for https://bigquant.com/wiki/topic/6d57b512c4: No
# Page usefulness for http://www.cfachina.org/servicesupport/researchandpublishin/publication/chinafutures/2012/zgqh2012_6_30/201301/t20130122_16624.html: No
# Page usefulness for https://m.yicai.com/brief/101997735.html: No
# Page usefulness for https://finance.sina.cn/2024-02-26/detail-inakkkhc1807233.d.html?from=wap: No
# Page usefulness for https://www.stcn.com/article/detail/1398881.html: No
# Page usefulness for https://xueqiu.com/2042982853/259727298: No
# Page usefulness for https://www.gov.cn/zhengce/content/202404/content_6944877.htm: No
# Page usefulness for https://news.qq.com/rain/a/20240516A01VZ700: No
# Page usefulness for http://finance.people.com.cn/BIG5/n1/2024/0221/c1004-40180741.html: No
# Page usefulness for https://blog.csdn.net/guzhoumingyue/article/details/141531263: No
# Page usefulness for https://xueqiu.com/8185159194/277790290: No
# Page usefulness for https://www.jiemian.com/article/12144796.html: No
# Page usefulness for https://www.cfachina.org/industrydynamics/mediaviewoffuturesmarket/202405/t20240524_73468.html: No
# Page usefulness for https://news.sina.com.cn/c/2024-07-10/doc-inccshzt5854669.shtml: No
# Page usefulness for https://www.incredibuild.cn/blog/quant-trading-strategies-definitions-and-importance: No
# Page usefulness for https://www.thepaper.cn/newsDetail_forward_23333762: No
# Page usefulness for https://www.icbc-ltd.com/icbc/%E7%BD%91%E4%B8%8A%E7%90%86%E8%B4%A2/%E4%B8%93%E5%AE%B6%E8%A7%86%E7%82%B9/%E6%9D%8E%E5%9F%9F/%E4%B8%93%E8%AE%BF%E5%85%A8%E5%9B%BD%E6%94%BF%E5%8D%8F%E5%A7%94%E5%91%98%E4%B8%AD%E5%A4%AE%E8%B4%A2%E7%BB%8F%E5%A4%A7%E5%AD%A6%E8%AF%81%E5%88%B8%E6%9C%9F%E8%B4%A7%E7%A0%94%E7%A9%B6%E6%89%80%E6%89%80%E9%95%BF%E8%B4%BA%E5%BC%BA%E9%87%8F%E5%8C%96%E4%BA%A4%E6%98%93%E9%9C%80%E5%8A%A0%E5%BC%BA%E7%9B%91%E7%AE%A1%E7%8B%AC%E7%AB%8B%E9%94%80%E5%94%AE%E6%9C%BA%E6%9E%84%E6%9C%89%E5%8A%A9%E4%BA%8E%E6%8A%95%E9%A1%BE%E8%A1%8C%E4%B8%9A%E5%8F%91%E5%B1%95.htm: No
# Page usefulness for https://blog.csdn.net/u012724887/article/details/115180386: No
# Page usefulness for http://www.cbimc.cn/content/2023-11/07/content_499305.html: No
# Page usefulness for https://www.yicai.com/news/101850621.html: No
# Page usefulness for https://www.lingjuninvest.com/news/4602: No
# Page usefulness for https://www.cls.cn/detail/642530: No
# Page usefulness for https://www.feishu.cn/content/what-does-quantitative-trading-mean: No
# Page usefulness for https://qzc.tsinghua.edu.cn/info/1194/2073.htm: No
# Page usefulness for https://www.stcn.com/article/detail/1207365.html: No
# Page usefulness for https://www.jianshu.com/p/7f1806ca2832: No
# Page usefulness for https://bigquant.com/wiki/doc/6yep5yyw5lqk5pit5piv5lua5lmip8kgiowqmanwfpemxqoejia-7hUcXKutKq: No
# Page usefulness for https://53ai.com/news/zhinenghuagaizao/2024111237581.html: No
# Page usefulness for https://caifuhao.eastmoney.com/news/20210108103258252311800: No
# Page usefulness for https://project256.com/quant/量化交易之路——策略实践: No
# Page usefulness for https://www.53ai.com/news/qianyanjishu/885.html: No
# Page usefulness for https://www.thepaper.cn/newsDetail_forward_26465119: No
# Page usefulness for https://invest.howlifeusa.com/zh/quantitative-trading/: No
# Page usefulness for https://stock.finance.sina.com.cn/stock/go.php/vReport_Show/kind/lastest/rptid/771916108406/index.phtml: No
# Page usefulness for https://xueqiu.com/6143089075/279218623: No
# Page usefulness for https://bigquant.com/wiki/doc/xKO5e4qSRT: No
# Page usefulness for https://www.cblco.cn/articlecontent/127.html: No
# Page usefulness for https://www.stcn.com/article/detail/1124644.html: No
# Page usefulness for https://m.thepaper.cn/baijiahao_26465119: No
# Page usefulness for https://mp.ofweek.com/finance/a656714951537: No
# Page usefulness for https://fisf.fudan.edu.cn/ffr/content/17: Yes
# Failed to extract content from: https://www.cmcmarkets.com/zh/trading-guides/quantitative-trading
# Page usefulness for https://xueqiu.com/4382174960/290195734: Yes
# Failed to extract content from: https://com.nycu.edu.tw/index.php?option=module&lang=cht&task=pageinfo&id=1961&index=1
# Failed to extract content from: https://medium.com/@newbloc2019/%E4%BC%A0%E7%BB%9F%E9%87%8F%E5%8C%96%E5%B7%B2%E6%AD%BB-ai%E9%87%8F%E5%8C%96%E4%B8%BA%E7%8E%8B-f703298d31b6
# Failed to extract content from: https://www.instagram.com/ntust.official/?locale=ru&hl=am-et
# Failed to extract content from: https://ru.pinterest.com/pin/1086000897640238735
# Failed to extract content from: https://ru.pinterest.com/pin/1059753356063656481
# Page usefulness for https://econ.pku.edu.cn/xkzy/jrxx/xkdt2/xkdtzs/377864.htm: No
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Page usefulness for https://www.tenlong.com.tw/products/9787113257842: Yes
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Request failed: 'choices'
# Page usefulness for https://bigquant.com/wiki/doc/6zpgfrwvNI: No
# Page usefulness for https://cloud.tencent.com/developer/article/2410299: No
# Page usefulness for https://blog.csdn.net/sohoqq/article/details/142632119: No
# Page usefulness for https://www.xhz.cn/zuixinzixun/48296.html: No
# Page usefulness for https://blog.csdn.net/qq_36545573/article/details/145187690: No
# Page usefulness for https://www.arx.cfa/~/media/8929A75120EB49E9B6A55DCBAD1951C6.ashx: No
# Page usefulness for https://cloud.tencent.com/developer/article/1652950: No
# Page usefulness for http://www.haiwen-law.com/35/1041: No
# Page usefulness for https://bigquant.com/wiki/doc/7hUcXKutKq: No
# Page usefulness for https://baijiahao.baidu.com/s?id=1780059107604500384: No
# Page usefulness for https://blog.csdn.net/xx16755498986/article/details/137965620: No
# Page usefulness for https://www.dongaigc.com/a/ai-quantitative-trading-exploration: No
# Page usefulness for https://m.gelonghui.com/p/29999: No
# Page usefulness for https://cjoe.cjoe.ac.cn/EN/10.12012/CJoE2023-0172: No
# Page usefulness for https://blog.csdn.net/2401_85338387/article/details/139327182: No
# Page usefulness for https://bigquant.com/wiki/topic/d9897c2ea3: No
# Page usefulness for https://econ.fudan.edu.cn/info/1582/26807.htm: No
# Page usefulness for https://centralasia.media/search:%E6%BE%B3%E6%B4%B2%E4%B8%93%E4%B8%9A%E6%89%93%E6%89%8BTelegram%E3%80%90@bkzn58%E3%80%91%E7%94%B5%E6%8A%A5.0804: No
# Page usefulness for https://www.qchaos.com/quantum_academy/basic_knowledge/6833/: No
# Page usefulness for https://cloud.tencent.com/developer/article/1168076: No
# Page usefulness for https://centralasia.media/search:%E7%BD%91%E4%B8%8A%E9%9F%A9%E5%9B%BD%E8%81%8C%E4%B8%9A%E6%9D%80%E6%89%8BTelegram%E3%80%90@bkzn58%E3%80%91%E7%94%B5%E6%8A%A5.0811: No
# Page usefulness for https://www.quantinfo.com/Article/View/2100.html: No
# Page usefulness for https://www.ciicmc.com/nciichr/zyzx96/xydc/xsryjl/871440/index.html: No
# Page usefulness for https://worktile.com/blog/shi-yao-shi-ji-xiao-kao-he-zhi-biao-liang-hua-de-fang-fa/: No
# Page usefulness for https://www.imooc.com/article/356827: No
# Page usefulness for https://finthon.com/risk-evaluation-indicators/: No
# Page usefulness for https://bigquant.com/wiki/doc/5py65zmo5a2m5lmg6yep5yyw5oqv6lwe5a6e5oiy5oyh5y2x-xKO5e4qSRT: No
# Page usefulness for https://bigquant.com/wiki/doc/Uu3N6WbJNJ: No
# Page usefulness for https://datacube.foundersc.com/document/41?doc_id=90: No
# Page usefulness for https://heth.ink/QuantStat/: No
# Page usefulness for https://docs.pingcode.com/ask/ask-ask/189507.html: No
# Request failed: 'choices'
# Page usefulness for https://www.liu-shen.com/Content-3510.html: No
# Page usefulness for https://www.jianshu.com/p/a74b56dd8f9a: No
# Page usefulness for https://www.jiqizhixin.com/articles/2019-01-30-13: No
# Page usefulness for http://www.woshipm.com/pmd/232069.html: No
# Page usefulness for https://editverse.com/ru/%D0%94%D0%B0%D1%82%D0%B0-%D0%B2%D1%8B%D1%85%D0%BE%D0%B4%D0%B0-2025-c/: No
# Page usefulness for https://www.metatrend.cc/web3/4618: No
# Page usefulness for https://www.cnblogs.com/qteasy/p/18064922: No
# Request failed: 'choices'
# Page usefulness for https://docs.pingcode.com/ask/280677.html: Yes
# Page usefulness for https://xueqiu.com/6916781846/320586601: Yes
# Extracted context from https://docs.pingcode.com/ask/280677.html (first 200 chars): AI量化交易是一种以人工智能为基础、结合计量经济学模型进行交易策略设计的高科技交易方式。它通过模拟大量历史数据，挖掘有效的交易规律、管理交易风险、并最终自动执行买卖决策。特别是在金融市场分析和预测、市场行情的实时处理等方面，AI量化交易显示出了传统手工交易无法比拟的优势，例如其可通过大数据分析实现更客观的市场判断，减少情绪波动对交易决策的影响。此外，AI的高频交易能力远超人类，能在短时间内分析并完
# Extracted context from https://xueqiu.com/6916781846/320586601 (first 200 chars): AI量化交易是利用人工智能技术（如机器学习、深度学习、自然语言处理等）来设计、优化和执行交易策略的一种方法。它通过分析海量数据，发现市场规律，并自动化交易决策，从而提高交易效率和准确性。
#
# 一、AI量化交易的核心技术
# 1. 机器学习（Machine Learning）：通过分析历史数据，识别市场趋势和模式，预测未来价格走势。常用模型包括神经网络、支持向量机（SVM）、随机森林等。
# 2. 深度学习（
# LLM provided new search queries: ['量化交易的伦理问题', '量化交易的社会影响', '量化交易的教育与培训', '量化交易的跨学科研究']
#
# Generating final report...
#
# ==== FINAL REPORT ====
#
# # 量化交易的前世今生
#
# ## 引言
# 量化交易（Quantitative Trading）是一种利用数学模型和计算机算法进行金融市场交易的策略。它依赖于大量的数据分析，通过统计学、数学建模和计算机科学等技术，实现投资回报。随着技术的进步，量化交易在全球范围内迅速发展，特别是在人工智能（AI）技术的加持下，其未来发展前景广阔。
#
# ## 量化交易的基本要素
# 量化交易的基本要素包括数据收集、数据分析、策略制定和执行交易。
# 1. **数据收集**：获取历史和实时市场数据，如价格、成交量、财务报表等。
# 2. **数据分析**：使用统计学和算法分析数据，识别模式和趋势。
# 3. **策略制定**：根据数据分析结果制定交易策略，如套利策略、趋势跟随策略等。
# 4. **执行交易**：通过交易系统自动执行策略生成的买入和卖出指令。
#
# ## 量化交易的发展历程
# 量化交易起源于20世纪70年代，随着计算机技术的发展，逐渐成为金融市场的主流投资方式之一。近年来，全球范围内针对量化交易的监管政策逐渐加强，原因包括市场操纵风险、不公平竞争、黑箱效应、系统性风险以及技术故障与安全隐患。监管措施包括提高透明度、增加资本要求、监测市场活动和限制高频交易。
#
# ## 量化交易的策略
# 常见的量化交易策略包括：
# - **趋势跟踪类策略**：如海龟策略、双均线策略。
# - **均值回归类策略**：如期货日线布林带策略。
# - **套利类策略**：如配对交易策略。
# - **市场中性类策略**：如多条件选股策略。
# - **高频交易（HFT）类策略**：如期货AR分钟策略。
# - **统计类套利策略**：如GBDT多因子选股策略。
# - **AI人工智能机器学习类策略**：如TALIB指标选股策略。
# - **事件驱动类策略**：如股票事件驱动策略。
#
# ## AI量化交易的核心技术
# AI量化交易利用人工智能技术（如机器学习、深度学习、自然语言处理等）来设计、优化和执行交易策略。
# 1. **机器学习（Machine Learning）**：通过分析历史数据，识别市场趋势和模式，预测未来价格走势。常用模型包括神经网络、支持向量机（SVM）、随机森林等。
# 2. **深度学习（Deep Learning）**：利用深度神经网络处理复杂数据（如图像、文本），提取非线性关系。
# 3. **强化学习（Reinforcement Learning）**：通过与市场环境交互，学习最优交易策略。
# 4. **自然语言处理（NLP）**：分析新闻、社交媒体、财报等文本数据，提取市场情绪和事件影响。
#
# ## AI量化交易的应用场景
# 1. **股票市场**：使用AI进行选股、择时和组合优化。
# 2. **期货与外汇市场**：利用AI预测价格波动和执行套利策略。
# 3. **加密货币市场**：通过AI分析高波动性市场中的交易机会。
# 4. **风险管理**：AI可以实时监控市场风险，动态调整仓位和止损点，降低投资组合的波动性。
#
# ## AI量化交易的优势
# 1. **高效数据处理**：AI可以快速分析海量数据，发现人类难以察觉的模式。
# 2. **自适应性强**：AI模型可以不断学习和调整，适应变化的市场环境。
# 3. **去情绪化**：AI交易决策基于数据和算法，避免了人为情绪的干扰。
# 4. **实时执行**：AI可以在毫秒级别做出决策并执行交易，把握稍纵即逝的机会。
#
# ## AI量化交易的挑战
# 1. **数据质量**：高质量的数据是AI模型的基础，但金融数据可能存在噪声和缺失。
# 2. **过拟合风险**：模型可能在历史数据上表现优异，但在实际交易中失效。
# 3. **技术门槛**：开发和维护AI量化交易系统需要编程、数学和金融知识。
#
# ## 量化交易的未来发展方向
# 1. **多模态融合**：结合价格、基本面、新闻、社交媒体等多源数据，构建更全面的决策模型。
# 2. **可解释AI**：提高AI模型的可解释性，增强投资者对模型决策的信任。
# 3. **量子计算**：利用量子计算的优势，解决传统计算难以处理的复杂金融问题。
#
# ## 结论
# 量化交易作为一种利用数学模型和计算机算法进行金融市场交易的策略，正在全球范围内迅速发展。特别是在人工智能技术的加持下，量化交易正站在新的风口上。未来，量化交易将继续保持增长势头，成为金融市场的主流投资方式之一。然而，随着技术的不断进步，量化交易也面临着数据质量、过拟合风险和技术门槛等挑战。因此，未来的发展需要在创新和合规之间找到平衡点，确保交易的透明度和公平性。

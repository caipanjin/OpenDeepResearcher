# %% [markdown]
# <a href="https://colab.research.google.com/github/mshumer/OpenDeepResearcher/blob/main/open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /opt/homebrew/lib/python3.11/site-packages (1.6.0)

# %%
import trafilatura
import asyncio
import aiohttp
import json

# =======================
# Configuration Constants
# =======================
DEEPSEEK_API_KEY = "" # Replace with your DEEPSEEK API key


# Endpoints
DEEPSEEK_URL = "https://api.siliconflow.cn/v1/chat/completions"

SEARXNG_INSTANCE = "http://localhost:18888"  # 选择一个可用的 SearXNG 实例 参考：https://searx.space/ 或者本地部署：docker run -d --name searxng -p 8888:8080 searxng/searxng

# Default LLM model (can be changed if desired)
DEFAULT_MODEL = "deepseek-ai/DeepSeek-V3"


# ============================
# Asynchronous Helper Functions
# ============================

async def call_openrouter_async(session, messages, model=DEFAULT_MODEL):
    """
    Asynchronously call the OpenRouter chat completion API with the provided messages.
    Returns the content of the assistant’s reply.
    """
    headers = {
        "Authorization": f"Bearer {DEEPSEEK_API_KEY}",
        "X-Title": "OpenDeepResearcher, by Matt Shumer",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": messages
    }
    try:
        async with session.post(DEEPSEEK_URL, headers=headers, json=payload) as resp:
            if resp.status == 200:
                result = await resp.json()
                try:
                    return result['choices'][0]['message']['content']
                except (KeyError, IndexError) as e:
                    print("Unexpected OpenRouter response structure:", result)
                    return None
            else:
                text = await resp.text()
                print(f"OpenRouter API error: {resp.status} - {text}")
                return None
    except Exception as e:
        print("Error calling OpenRouter:", e)
        return None


async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            search_queries = eval(response)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    params = {"q": query, "format": "json"}
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
    }
    try:
        async with session.get(SEARXNG_INSTANCE + "/search", params=params, headers=headers) as resp:
            if resp.status == 200:
                data = await resp.json()
                links = [result["url"] for result in data.get("results", [])]
                return links
            else:
                print(f"SearXNG error: {resp.status}")
                return []
    except Exception as e:
        print("Error performing SearXNG search:", e)
        return []

async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await call_openrouter_async(session, messages)
    return report


async def fetch_webpage_text_async(link):
    """
    使用 trafilatura 异步提取网页主要内容。
    """
    loop = asyncio.get_event_loop()
    downloaded = await loop.run_in_executor(None, trafilatura.fetch_url, link)
    if downloaded:
        text = await loop.run_in_executor(None, trafilatura.extract, downloaded)
        return text
    return None

async def process_link(session, link, user_query, search_query):
    """
    处理单个链接：获取内容，判断是否有用，并提取相关上下文。
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(link)
    if not page_text:
        print(f"Failed to extract content from: {link}")
        return None

    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")

    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context

    return None

    
# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic:  黄金、美元、人民币最近10年（2015年到2025年）来的变化趋势和原因分析。
# Enter maximum number of iterations (default 10):  1
# === Iteration 1 ===
# Aggregated 155 unique links from this iteration.
# Fetching content from: https://gold.hexun.com/2025-02-06/217126597.html
# Fetching content from: https://www.litefinance.org/zh/blog/analysts-opinions/huang-jin-jia-ge-yu-gu-yu-ce/
# Fetching content from: https://privatebank.jpmorgan.com/apac/cn/insights/markets-and-investing/is-it-a-golden-era-for-gold
# Fetching content from: https://www.cmegroup.com/cn-s/education/futures-daily/2025-01-23.html
# Fetching content from: https://finance.sina.com.cn/money/nmetal/hjzx/2025-01-14/doc-ineeyzvf8100714.shtml
# Fetching content from: https://www.bbc.com/ukchina/simp/53702934
# Fetching content from: https://china.gold.org/goldhub/research/publication/2024/12/06/18865
# Fetching content from: https://pdf.dfcfw.com/pdf/H3_AP202412251641429630_1.pdf?1735160486000.pdf
# Fetching content from: https://www.gold678.com/C/202501302146498810
# Fetching content from: https://baijiahao.baidu.com/s?id=1821041133688560407
# Fetching content from: http://maseh.sn/sasa
# Fetching content from: https://www.sohu.com/a/854499685_121976698
# Fetching content from: http://tezitnot.li/ahwem
# Fetching content from: https://www.sohu.com/a/855106022_121976698
# Fetching content from: http://nod.se/dokakig
# Fetching content from: https://www.toutiao.com/article/7410590840726225448/
# Fetching content from: http://gabja.ro/bawkeuf
# Fetching content from: https://baijiahao.baidu.com/s?id=1817796783156557716
# Fetching content from: https://www.21jingji.com/article/20250205/herald/e5ddf86ba9d51871305665540218cd71.html
# Fetching content from: https://www.cmegroup.com/cn-s/education/7he/2024-02-09.html
# Fetching content from: https://m.thepaper.cn/newsDetail_forward_30082555
# Fetching content from: https://m.bankcomm.com/wap/shtml/wap/cn/15539/15566/15568/8168557.shtml?channelId=15539
# Fetching content from: https://www.cmegroup.com/cn-s/articles/2023/what-next-for-gold.html
# Fetching content from: https://finance.sina.com.cn/money/bond/2025-01-02/doc-inecprkm2676737.shtml
# Fetching content from: https://www.cmegroup.com/cn-s/insights/economic-research/2024/gold-will-2024-be-a-breakout-year-on-rate-cut-hopes.html
# Fetching content from: https://www.ccbfutures.com/upload/20241025/20241025133607439.pdf
# Fetching content from: https://www.cmegroup.com/cn-s/education/featured-reports/gold-impact-from-us-and-chinese-policies.html
# Fetching content from: http://jisi.ck/jetvaf
# Fetching content from: https://xueqiu.com/3787594483/318278140
# Fetching content from: http://ubu.tc/melosa
# Fetching content from: http://jullawo.at/jisfazfe
# Fetching content from: https://china.gold.org/goldhub/research/publication/2024/12/12/18905
# Fetching content from: http://beb.lu/elkah
# Fetching content from: http://cif.tv/dovohe
# Fetching content from: https://www.fxopen-zh.com/cn/market-analytics/analytical-gold-price-predictions-for-2025-and-beyond/
# Fetching content from: http://pi.ma/heki
# Fetching content from: https://www.moomoo.com/hans/news/post/47593988/will-gold-continue-to-shine-in-2025-a-review-from
# Fetching content from: http://intl.ce.cn/specials/zxxx/201307/30/t20130730_24618716.shtml
# Fetching content from: https://www.cmegroup.com/cn-s/insights/economic-research/2023/gold-the-often-unseen-hand-of-supply-in-long-term-price-discovery.html
# Fetching content from: https://chl.cn/huilv/
# Fetching content from: https://stcn.com/article/detail/1477761.html
# Fetching content from: https://finance.sina.com.cn/stock/zqgd/2025-01-12/doc-ineeseki3709650.shtml
# Fetching content from: https://m.mofcom.gov.cn/article/scjc/jcgjzysp/201509/20150901105896.shtml
# Fetching content from: https://price.mofcom.gov.cn/article/yjzx/yjbg/gjsczyspjgjcnb/202302/59093.html
# Fetching content from: https://finance.sina.com.cn/roll/2024-12-27/doc-ineawtrs7155129.shtml
# Fetching content from: https://m.mofcom.gov.cn/article/scjc/jcgjzysp/201603/20160301287194.shtml
# Fetching content from: https://finance.sina.com.cn/money/future/roll/2025-01-23/doc-inefykkt5890041.shtml
# Fetching content from: https://www.htsec.com/jfimg/colimg/upload/20241227/1735264077436051159.pdf
# Fetching content from: http://m.safe.gov.cn/safe/2015/1231/6038.html
# Fetching content from: https://finance.sina.com.cn/money/bond/2025-01-02/doc-inecqhfz5664546.shtml
# Fetching content from: https://www.icbc.com.cn/column/1438058341489590354.html
# Fetching content from: https://finance.sina.com.cn/roll/2025-01-11/doc-ineerawv4310916.shtml
# Fetching content from: https://wallstreetcn.com/articles/3738308
# Fetching content from: https://iftp.chinamoney.com.cn/chinese/bkccpr/
# Fetching content from: https://finance.sina.com.cn/money/forex/forexinfo/2024-11-11/doc-incvscvr7580600.shtml
# Fetching content from: https://cn.investing.com/currencies/usd-cny
# Fetching content from: https://xueqiu.com/1459344167/321807417
# Fetching content from: http://awjohlo.cc/mo
# Fetching content from: https://www.sohu.com/a/855122770_122066678
# Fetching content from: http://gewwe.af/za
# Fetching content from: https://www.sohu.com/a/854625111_122033970
# Fetching content from: http://zegibeh.kr/go
# Fetching content from: https://finance.sina.com.cn/cj/2025-01-21/doc-ineftrwv8490933.shtml
# Fetching content from: http://cihir.tk/jigatojo
# Fetching content from: https://xueqiu.com/1855126975/319657019
# Fetching content from: http://rdcy.ruc.edu.cn/zw/jszy/rdcy/grzl_rdcy/bf351b1d58ee4b01be934af7c42d97f7.htm
# Fetching content from: https://www.21jingji.com/article/20250104/2af4fece4f00071480718f3f7d43b5a0.html
# Fetching content from: https://finance.sina.com.cn/stock/stockzmt/2025-01-13/doc-ineevkuz9745855.shtml
# Fetching content from: https://stock-hexun-com.webvpn.imac.edu.cn/2023-10-22/210706678.html
# Fetching content from: https://longforecast.cn/
# Fetching content from: https://www.hsbc.com.hk/zh-cn/wealth/insights/fx-insights/fx-viewpoint/2025-01-20/
# Fetching content from: https://cn.investing.com/indices/usdollar
# Fetching content from: http://ier.ruc.edu.cn/docs/2023-12/95dc7f3e3c114a408d337225d877aada.pdf
# Fetching content from: http://pulwopa.so/zinguz
# Fetching content from: https://www.sohu.com/a/844783463_121994931
# Fetching content from: http://zoc.ht/vo
# Fetching content from: http://jihar.edu/bi
# Fetching content from: https://tradexplore.com/sc/market-knowledge/forex/usd-forecast/
# Fetching content from: http://lijnoh.pn/bugga
# Fetching content from: https://baijiahao.baidu.com/s?id=1819298224071289290
# Fetching content from: http://uc.mp/toweswu
# Fetching content from: https://finance.caixin.com/2024-12-31/102274223.html
# Fetching content from: https://www.gov.cn/xinwen/2015-08/11/content_2911052.htm
# Fetching content from: https://wallstreetcn.com/articles/3737394
# Fetching content from: https://finance.sina.com.cn/jjxw/2025-01-26/doc-inehhvfz9899265.shtml
# Fetching content from: https://www.cmegroup.com/cn-s/education/jinrongjie/2024-01-05.html
# Fetching content from: https://www.safe.gov.cn/AppStructured/hlw/RMBQuery.do
# Fetching content from: https://cn.investing.com/currencies/usd-cny-historical-data
# Fetching content from: https://www.ndrc.gov.cn/wsdwhfz/202501/t20250122_1395842.html
# Fetching content from: http://m.safe.gov.cn/safe/2015/0630/6032.html
# Fetching content from: https://cn.investing.com/currencies/usd-cny-chart
# Fetching content from: http://curahi.ng/ikubo
# Fetching content from: https://www.cmegroup.com/cn-s/education/jinrongjie/2024-04-12.html
# Fetching content from: https://www.cmegroup.com/cn-s/education/7he/2025-01-10.html
# Fetching content from: https://www.mitrade.com/cn/insights/forex/us-dollar/us-dollar-trend
# Fetching content from: https://finance.sina.com.cn/jjxw/2025-01-11/doc-ineepqvm5665736.shtml
# Fetching content from: https://wap.eastmoney.com/a/202501113294024571.html
# Fetching content from: https://qks.sufe.edu.cn/j/PDFFull/A170119000009.pdf
# Fetching content from: https://baijiahao.baidu.com/s?id=1823194614342677783
# Fetching content from: http://ere.bj/fan
# Fetching content from: http://zas.tg/co
# Fetching content from: http://zez.gov/kov
# Fetching content from: https://baijiahao.baidu.com/s?id=1817500395412099530
# Fetching content from: http://raegece.by/bob
# Fetching content from: https://news.qq.com/rain/a/20250108A08BAY00
# Fetching content from: http://anuasikab.cm/raw
# Fetching content from: http://www.pbc.gov.cn/goutongjiaoliu/113456/113469/3198768/index.html
# Fetching content from: https://finance.caixin.com/2025-01-13/102278452.html
# Fetching content from: http://www.cb.com.cn/index/show/bzyc/cv/cv135241831643
# Fetching content from: http://www.iwep.org.cn/xscg/xscg_sp/201502/t20150211_1901946.shtml
# Fetching content from: https://qks.sufe.edu.cn/mv_html/j00001/201701/4a265b3f-517d-469a-b80d-afdca61db234_WEB.htm
# Fetching content from: http://m.ce.cn/cj/gd/202501/07/t20250107_39258234.shtml
# Fetching content from: https://www.boc.cn/sourcedb/whpj/
# Fetching content from: https://www.stcn.com/article/detail/1514691.html
# Fetching content from: https://www.sohu.com/a/855161203_122066678
# Fetching content from: http://ik.ye/eje
# Fetching content from: https://www.sohu.com/a/844368592_121994931
# Fetching content from: http://mot.ss/gadbeek
# Fetching content from: https://finance.sina.cn/2025-01-11/detail-ineerawv4310916.d.html
# Fetching content from: http://cibi.tm/si
# Fetching content from: https://www.36kr.com/p/3105003558751745
# Fetching content from: http://ba.qa/riswet
# Fetching content from: https://zhuanlan.zhihu.com/p/650193724
# Fetching content from: https://finance.sina.com.cn/cj/2025-01-10/doc-ineentrv6071047.shtml
# Fetching content from: https://iftp.chinamoney.com.cn/chinese/forsddshis/index.html?dataType=6
# Fetching content from: http://www.pbc.gov.cn/zhengcehuobisi/125207/125217/125925/index.html
# Fetching content from: https://cj.sina.com.cn/articles/view/6314832590/17864b2ce00101agcy
# Fetching content from: https://finance.sina.com.cn/cj/2025-01-11/doc-ineerpnp4631378.shtml
# Fetching content from: https://www.mastercard.com.cn/zh-cn/personal/get-support/convert-currency.html
# Fetching content from: https://finance.sina.com.cn/cj/2024-12-04/doc-incyhuet0699841.shtml
# Fetching content from: http://fo.gt/lemrij
# Fetching content from: https://opinion.caixin.com/2025-01-13/102278424.html
# Fetching content from: https://www.services.cn-banking.hsbc.com.cn/PublicContent/common/rate/zh/exchange-rates.html
# Fetching content from: https://wallstreetcn.com/articles/3736571
# Fetching content from: http://www.pbc.gov.cn/WZWSREL2dvdXRvbmdqaWFvbGl1LzExMzQ1Ni8xMTM0NjkvMjgxMzg3OS9pbmRleC5odG1s
# Fetching content from: https://pic.bankofchina.com/bocappd/rareport/202411/P020241128350229527110.pdf
# Fetching content from: https://wallstreetcn.com/articles/3738294
# Fetching content from: https://finance.sina.com.cn/cj/2025-01-03/doc-inecrcmn9511814.shtml
# Fetching content from: http://saf.tc/rivaw
# Fetching content from: http://uv.lk/niapukiw
# Fetching content from: https://xueshu.baidu.com/usercenter/paper/show?paperid=e89f569d7a6bb01e05926e5e5323af88
# Fetching content from: http://ba.lk/giemeku
# Fetching content from: http://cog.za/ciuderaz
# Fetching content from: https://china.gold.org/goldhub/data
# Fetching content from: http://sitbus.com/ce
# Fetching content from: https://stock.finance.sina.com.cn/stock/go.php/vReport_Show/kind/11/rptid/784657092802/index.phtml
# Fetching content from: http://azzut.lt/bi
# Fetching content from: https://xueshu.baidu.com/usercenter/paper/show?paperid=1e440ae0us270eq0ha2x08g0mx084966&site=xueshu_se
# Fetching content from: http://dalasro.tr/mak
# Fetching content from: http://qikan.cqvip.com/Qikan/Article/Detail?id=7108067916
# Fetching content from: http://diffel.az/edgo
# Fetching content from: http://ikuro.mk/kono
# Fetching content from: https://finance.sina.com.cn/money/nmetal/hjzx/2024-05-21/doc-inavxtkx0449166.shtml
# Fetching content from: https://finance.sina.cn/futuremarket/qsyw/2025-01-14/detail-ineeyzvf8100714.d.html?oid=%EF%BB%BFFb777%20casino%20login%3E%3ECC6.BetCC6.Bet&vt=4&cid=76596&node_id=76596
# Fetching content from: http://jeanat.gr/tukhil
# Failed to extract content from: http://tezitnot.li/ahwem
# Failed to extract content from: http://gabja.ro/bawkeuf
# Failed to extract content from: http://maseh.sn/sasa
# Failed to extract content from: http://jisi.ck/jetvaf
# Failed to extract content from: http://nod.se/dokakig
# Failed to extract content from: http://jullawo.at/jisfazfe
# Failed to extract content from: http://ubu.tc/melosa
# Failed to extract content from: http://beb.lu/elkah
# Failed to extract content from: http://cif.tv/dovohe
# Failed to extract content from: http://pi.ma/heki
# Failed to extract content from: http://awjohlo.cc/mo
# Failed to extract content from: https://cn.investing.com/currencies/usd-cny
# Failed to extract content from: http://zegibeh.kr/go
# Failed to extract content from: http://cihir.tk/jigatojo
# Failed to extract content from: http://gewwe.af/za
# Failed to extract content from: https://cn.investing.com/indices/usdollar
# Failed to extract content from: http://pulwopa.so/zinguz
# Failed to extract content from: http://zoc.ht/vo
# Failed to extract content from: http://jihar.edu/bi
# Failed to extract content from: http://lijnoh.pn/bugga
# Failed to extract content from: http://uc.mp/toweswu
# Failed to extract content from: https://www.cmegroup.com/cn-s/education/futures-daily/2025-01-23.html
# Failed to extract content from: https://www.cmegroup.com/cn-s/education/7he/2024-02-09.html
# Failed to extract content from: https://www.cmegroup.com/cn-s/articles/2023/what-next-for-gold.html
# Failed to extract content from: https://m.bankcomm.com/wap/shtml/wap/cn/15539/15566/15568/8168557.shtml?channelId=15539
# Failed to extract content from: https://www.cmegroup.com/cn-s/insights/economic-research/2024/gold-will-2024-be-a-breakout-year-on-rate-cut-hopes.html
# Failed to extract content from: https://www.cmegroup.com/cn-s/education/featured-reports/gold-impact-from-us-and-chinese-policies.html
# Failed to extract content from: http://curahi.ng/ikubo
# Failed to extract content from: https://www.bbc.com/ukchina/simp/53702934
# Failed to extract content from: http://ere.bj/fan
# Failed to extract content from: https://www.fxopen-zh.com/cn/market-analytics/analytical-gold-price-predictions-for-2025-and-beyond/
# Failed to extract content from: https://www.cmegroup.com/cn-s/insights/economic-research/2023/gold-the-often-unseen-hand-of-supply-in-long-term-price-discovery.html
# Failed to extract content from: https://cn.investing.com/currencies/usd-cny-historical-data
# Failed to extract content from: http://raegece.by/bob
# Failed to extract content from: https://www.moomoo.com/hans/news/post/47593988/will-gold-continue-to-shine-in-2025-a-review-from
# Failed to extract content from: http://www.pbc.gov.cn/goutongjiaoliu/113456/113469/3198768/index.html
# Failed to extract content from: http://anuasikab.cm/raw
# Failed to extract content from: https://price.mofcom.gov.cn/article/yjzx/yjbg/gjsczyspjgjcnb/202302/59093.html
# Failed to extract content from: http://mot.ss/gadbeek
# Failed to extract content from: http://cibi.tm/si
# Failed to extract content from: http://zas.tg/co
# Failed to extract content from: http://ba.qa/riswet
# Failed to extract content from: http://www.pbc.gov.cn/zhengcehuobisi/125207/125217/125925/index.html
# Failed to extract content from: http://zez.gov/kov
# Failed to extract content from: https://cn.investing.com/currencies/usd-cny-chart
# Failed to extract content from: http://fo.gt/lemrij
# Failed to extract content from: http://ik.ye/eje
# Failed to extract content from: https://zhuanlan.zhihu.com/p/650193724
# Failed to extract content from: http://www.pbc.gov.cn/WZWSREL2dvdXRvbmdqaWFvbGl1LzExMzQ1Ni8xMTM0NjkvMjgxMzg3OS9pbmRleC5odG1s
# Failed to extract content from: http://saf.tc/rivaw
# Failed to extract content from: http://uv.lk/niapukiw
# Failed to extract content from: http://ba.lk/giemeku
# Failed to extract content from: http://cog.za/ciuderaz
# Failed to extract content from: http://sitbus.com/ce
# Failed to extract content from: http://dalasro.tr/mak
# Failed to extract content from: http://qikan.cqvip.com/Qikan/Article/Detail?id=7108067916
# Failed to extract content from: http://azzut.lt/bi
# Failed to extract content from: http://ikuro.mk/kono
# Failed to extract content from: http://diffel.az/edgo
# Failed to extract content from: https://www.toutiao.com/article/7410590840726225448/
# Failed to extract content from: https://pdf.dfcfw.com/pdf/H3_AP202412251641429630_1.pdf?1735160486000.pdf
# Failed to extract content from: https://iftp.chinamoney.com.cn/chinese/bkccpr/
# Failed to extract content from: https://www.htsec.com/jfimg/colimg/upload/20241227/1735264077436051159.pdf
# Failed to extract content from: https://www.ccbfutures.com/upload/20241025/20241025133607439.pdf
# Failed to extract content from: http://ier.ruc.edu.cn/docs/2023-12/95dc7f3e3c114a408d337225d877aada.pdf
# Failed to extract content from: https://qks.sufe.edu.cn/j/PDFFull/A170119000009.pdf
# Failed to extract content from: https://www.36kr.com/p/3105003558751745
# Failed to extract content from: http://jeanat.gr/tukhil
# Page usefulness for https://www.gold678.com/C/202501302146498810: No
# Page usefulness for https://www.sohu.com/a/844368592_121994931: No
# Page usefulness for https://www.icbc.com.cn/column/1438058341489590354.html: No
# Page usefulness for https://china.gold.org/goldhub/data: No
# Page usefulness for https://finance.caixin.com/2025-01-13/102278452.html: No
# Page usefulness for http://rdcy.ruc.edu.cn/zw/jszy/rdcy/grzl_rdcy/bf351b1d58ee4b01be934af7c42d97f7.htm: Yes
# Page usefulness for https://finance.sina.com.cn/stock/zqgd/2025-01-12/doc-ineeseki3709650.shtml: Yes
# Page usefulness for https://m.thepaper.cn/newsDetail_forward_30082555: No
# Page usefulness for https://www.sohu.com/a/855122770_122066678: No
# Page usefulness for https://gold.hexun.com/2025-02-06/217126597.html: Yes
# Page usefulness for https://finance.sina.com.cn/roll/2024-12-27/doc-ineawtrs7155129.shtml: Yes
# Page usefulness for https://baijiahao.baidu.com/s?id=1819298224071289290: No
# Page usefulness for https://finance.caixin.com/2024-12-31/102274223.html: Yes
# Page usefulness for http://intl.ce.cn/specials/zxxx/201307/30/t20130730_24618716.shtml: No
# Page usefulness for http://m.safe.gov.cn/safe/2015/0630/6032.html: No
# Page usefulness for http://m.safe.gov.cn/safe/2015/1231/6038.html: No
# Page usefulness for https://wap.eastmoney.com/a/202501113294024571.html: No
# Page usefulness for https://xueqiu.com/1459344167/321807417: No
# Page usefulness for https://www.stcn.com/article/detail/1514691.html: No
# Page usefulness for https://finance.sina.com.cn/cj/2024-12-04/doc-incyhuet0699841.shtml: Yes
# Page usefulness for https://www.services.cn-banking.hsbc.com.cn/PublicContent/common/rate/zh/exchange-rates.html: No
# Page usefulness for https://m.mofcom.gov.cn/article/scjc/jcgjzysp/201603/20160301287194.shtml: No
# Page usefulness for https://privatebank.jpmorgan.com/apac/cn/insights/markets-and-investing/is-it-a-golden-era-for-gold: Yes
# Page usefulness for https://www.safe.gov.cn/AppStructured/hlw/RMBQuery.do: No
# Page usefulness for https://xueqiu.com/3787594483/318278140: Yes
# Page usefulness for https://baijiahao.baidu.com/s?id=1821041133688560407: Yes
# Page usefulness for http://www.iwep.org.cn/xscg/xscg_sp/201502/t20150211_1901946.shtml: No
# Page usefulness for https://www.hsbc.com.hk/zh-cn/wealth/insights/fx-insights/fx-viewpoint/2025-01-20/: No
# Page usefulness for https://www.ndrc.gov.cn/wsdwhfz/202501/t20250122_1395842.html: No
# Page usefulness for https://finance.sina.com.cn/money/nmetal/hjzx/2025-01-14/doc-ineeyzvf8100714.shtml: Yes
# Page usefulness for https://finance.sina.com.cn/money/future/roll/2025-01-23/doc-inefykkt5890041.shtml: No
# Page usefulness for https://stock-hexun-com.webvpn.imac.edu.cn/2023-10-22/210706678.html: No
# Page usefulness for https://news.qq.com/rain/a/20250108A08BAY00: Yes
# Page usefulness for https://finance.sina.com.cn/money/bond/2025-01-02/doc-inecprkm2676737.shtml: Yes
# Page usefulness for https://www.sohu.com/a/855161203_122066678: No
# Page usefulness for https://finance.sina.com.cn/money/bond/2025-01-02/doc-inecqhfz5664546.shtml: Yes
# Page usefulness for https://wallstreetcn.com/articles/3737394: Yes
# Page usefulness for https://xueshu.baidu.com/usercenter/paper/show?paperid=1e440ae0us270eq0ha2x08g0mx084966&site=xueshu_se: No
# Page usefulness for https://www.boc.cn/sourcedb/whpj/: No
# Page usefulness for https://finance.sina.com.cn/cj/2025-01-11/doc-ineerpnp4631378.shtml: Yes
# Page usefulness for https://www.21jingji.com/article/20250104/2af4fece4f00071480718f3f7d43b5a0.html: No
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://cj.sina.com.cn/articles/view/6314832590/17864b2ce00101agcy: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://finance.sina.com.cn/cj/2025-01-21/doc-ineftrwv8490933.shtml: Yes
# Page usefulness for https://finance.sina.cn/futuremarket/qsyw/2025-01-14/detail-ineeyzvf8100714.d.html?oid=%EF%BB%BFFb777%20casino%20login%3E%3ECC6.BetCC6.Bet&vt=4&cid=76596&node_id=76596: No
# Page usefulness for http://m.ce.cn/cj/gd/202501/07/t20250107_39258234.shtml: Yes
# Page usefulness for https://china.gold.org/goldhub/research/publication/2024/12/12/18905: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://finance.sina.com.cn/roll/2025-01-11/doc-ineerawv4310916.shtml: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://finance.sina.com.cn/jjxw/2025-01-11/doc-ineepqvm5665736.shtml: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://stock.finance.sina.com.cn/stock/go.php/vReport_Show/kind/11/rptid/784657092802/index.phtml: Yes
# Page usefulness for https://wallstreetcn.com/articles/3738294: Yes
# Page usefulness for https://baijiahao.baidu.com/s?id=1817796783156557716: No
# Page usefulness for https://finance.sina.com.cn/money/nmetal/hjzx/2024-05-21/doc-inavxtkx0449166.shtml: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://www.sohu.com/a/854499685_121976698: No
# Page usefulness for https://baijiahao.baidu.com/s?id=1817500395412099530: Yes
# Page usefulness for https://finance.sina.com.cn/cj/2025-01-03/doc-inecrcmn9511814.shtml: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://chl.cn/huilv/: No
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://tradexplore.com/sc/market-knowledge/forex/usd-forecast/: No
# Page usefulness for https://finance.sina.com.cn/jjxw/2025-01-26/doc-inehhvfz9899265.shtml: Yes
# Page usefulness for https://china.gold.org/goldhub/research/publication/2024/12/06/18865: Yes
# Page usefulness for https://www.gov.cn/xinwen/2015-08/11/content_2911052.htm: No
# Page usefulness for https://finance.sina.com.cn/cj/2025-01-10/doc-ineentrv6071047.shtml: No
# Page usefulness for https://baijiahao.baidu.com/s?id=1823194614342677783: No
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://longforecast.cn/: No
# Failed to extract content from: https://pic.bankofchina.com/bocappd/rareport/202411/P020241128350229527110.pdf
# Page usefulness for https://finance.sina.cn/2025-01-11/detail-ineerawv4310916.d.html: Yes
# Page usefulness for https://www.sohu.com/a/854625111_122033970: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://wallstreetcn.com/articles/3738308: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://finance.sina.com.cn/stock/stockzmt/2025-01-13/doc-ineevkuz9745855.shtml: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://www.litefinance.org/zh/blog/analysts-opinions/huang-jin-jia-ge-yu-gu-yu-ce/: No
# Page usefulness for https://wallstreetcn.com/articles/3736571: Yes
# Page usefulness for https://finance.sina.com.cn/money/forex/forexinfo/2024-11-11/doc-incvscvr7580600.shtml: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://m.mofcom.gov.cn/article/scjc/jcgjzysp/201509/20150901105896.shtml: No
# Page usefulness for https://www.sohu.com/a/844783463_121994931: No
# Page usefulness for https://xueqiu.com/1855126975/319657019: Yes
# Page usefulness for https://stcn.com/article/detail/1477761.html: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://www.mastercard.com.cn/zh-cn/personal/get-support/convert-currency.html: No
# Page usefulness for https://www.sohu.com/a/855106022_121976698: No
# Page usefulness for https://www.21jingji.com/article/20250205/herald/e5ddf86ba9d51871305665540218cd71.html: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Page usefulness for https://qks.sufe.edu.cn/mv_html/j00001/201701/4a265b3f-517d-469a-b80d-afdca61db234_WEB.htm: Yes
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# Extracted context from https://finance.caixin.com/2024-12-31/102274223.html (first 200 chars): 1. 2024年，美元指数的强劲表现对人民币造成一定的压力，汇率的波动较2023年有所下降，从2023年振幅超过9%下降至2024年的4%左右。
# 2. 影响人民币的外部因素主要来自美元指数，包括美联储货币政策、地缘政治风险等因素。
# 3. 内部因素方面，人民币汇率也受到中国贸易顺差、出口规模、经济增长等基本面因素影响，同时也可能受到季节性结售汇的影响。
# 4. 2024年上半年，由于美联储降息迟迟不落
# Failed to extract content from: https://www.cmegroup.com/cn-s/education/jinrongjie/2024-01-05.html
# Page usefulness for https://xueshu.baidu.com/usercenter/paper/show?paperid=e89f569d7a6bb01e05926e5e5323af88: No
# Extracted context from https://baijiahao.baidu.com/s?id=1821041133688560407 (first 200 chars): 1. 黄金价格在2015年到2025年间持续上涨，国际现货金价突破每盎司2600美元大关，且有望在2025年底飙升至3000美元每盎司。
# 2. 全球央行购金热潮是推动金价上涨的重要因素，中国、俄罗斯、印度、土耳其和巴西等新兴市场国家央行纷纷增加黄金储备，以实现储备资产多样化和降低对美元的依赖。
# 3. 全球经济不确定性增加，地缘政治风险如中东战争和俄乌冲突持续存在，导致投资者对经济和政治形势的担忧，
# Failed to extract content from: https://www.cmegroup.com/cn-s/education/jinrongjie/2024-04-12.html
# Failed to extract content from: https://www.cmegroup.com/cn-s/education/7he/2025-01-10.html
# Failed to extract content from: https://www.mitrade.com/cn/insights/forex/us-dollar/us-dollar-trend
# Extracted context from https://privatebank.jpmorgan.com/apac/cn/insights/markets-and-investing/is-it-a-golden-era-for-gold (first 200 chars): 黄金作为一种大宗商品，过去20年年化升值约达8%。从2011年到2015年期间，黄金价格曾暴跌约40%，直到2020年才完全收复失地。自2023年底以来，黄金经历了强劲的反弹，不断创下历史新高。2024年，黄金小幅领先于标普500指数，成为表现最佳的资产之一。展望2025年，预计黄金价格将达到每盎司3,150美元。
#
# 黄金价格受多种宏观因素影响，包括美元汇率水平、实际收益率的变化和供需动态。美元汇
# Extracted context from https://gold.hexun.com/2025-02-06/217126597.html (first 200 chars): - 2024年黄金价格大涨27.39%，2025年继续上涨超过7%，黄金价格再次创出历史新高。
# - 2024年黄金的市场表现基本上跑赢全球大多数的大类资产。
# - 2025年黄金价格继续大涨超过7%，跑赢全球多数大类资产的同期表现。
# - 黄金属于“无息资产”，不能产生利息收入或股息收入。
# - 黄金是抵御通胀的投资品种之一，在通胀长期升温的背景下，投资黄金是稳妥的选择。
# - 从长期来看，黄金价格基本上
# Failed to extract content from: http://www.cb.com.cn/index/show/bzyc/cv/cv135241831643
# Failed to extract content from: https://iftp.chinamoney.com.cn/chinese/forsddshis/index.html?dataType=6
# Extracted context from https://finance.sina.com.cn/roll/2024-12-27/doc-ineawtrs7155129.shtml (first 200 chars): 1. 2024年，黄金市场表现强劲，价格多次刷新历史高点。
# 2. 2024年10月31日，国际金价达到今年最高点2801.8美元。
# 3. 2025年，黄金价格有望开启新一轮上行周期，总体会在震荡中弱势上行。
# 4. 美联储降息政策、欧美经济复苏步伐稳定以及国内降准和降息措施为2025年黄金价格提供了一定支撑。
# 5. 2025年黄金价格预计将继续上涨，但相比2024年的强势上涨，波动性将显著增加，或呈
# Extracted context from https://news.qq.com/rain/a/20250108A08BAY00 (first 200 chars): 1. 人民币汇率在2025年预计将保持在7.10-7.35的波动区间内震荡。
# 2. 美国加征关税的时点和路径、“宽财政”政策加码的时点和规模等均存在较大不确定性，汇率预期或在矛盾切换中反复冲折。
# 3. 美元兑人民币汇率上行的幅度和节奏取决于关税政策落地的节奏和中美谈判的进展。
# 4. 在2025年对华加征关税政策正式落地之前，人民币兑美元总体上保持在7.10-7.35的波动区间内震荡。
# 5. 人民币
# Extracted context from http://rdcy.ruc.edu.cn/zw/jszy/rdcy/grzl_rdcy/bf351b1d58ee4b01be934af7c42d97f7.htm (first 200 chars): 1. 2024年人民币汇率走势的特点是贸易汇率与金融汇率之间出现了一定程度的背离：一篮子货币贸易汇率（CFETS）升值1.97%，人民币对美元汇率（金融汇率）贬值2.66%。
#
# 2. 2025年人民币汇率走势更可能是贸易汇率与金融汇率之间背离程度的收敛，人民币金融汇率走势与贸易汇率（CFETS）走势更可能趋向一致。
#
# 3. 2025年影响人民币汇率最重要的因素依然是我国经济的基本面，预计经济增速可
# Extracted context from https://finance.sina.com.cn/money/nmetal/hjzx/2025-01-14/doc-ineeyzvf8100714.shtml (first 200 chars): 1. 黄金价格在2015年跌至1049.4美元/盎司，此后进入低位震荡阶段。
# 2. 2018年开始的第三轮黄金周期中，黄金价格至2019年涨超2000美元/盎司，后高位震荡。
# 3. 2024年黄金价格屡创历史新高，突破了2383美元/盎司，主要原因包括国际地缘形势复杂、全球“去美元化”进程以及美元外汇储备下降、黄金储备上升。
# 4. 黄金价格与美元指数的强弱在大趋势上存在一定的负相关关系，当美元下跌
# Extracted context from https://finance.sina.com.cn/cj/2024-12-04/doc-incyhuet0699841.shtml (first 200 chars): 1. 2024年人民币汇率走势的特点是贸易汇率与金融汇率之间出现了一定程度的背离：一篮子货币贸易汇率（CFETS）升值1.97%，人民币对美元汇率（金融汇率）贬值2.66%。
# 2. 2025年人民币汇率走势更可能是贸易汇率与金融汇率之间背离程度的收敛，人民币金融汇率走势与贸易汇率（CFETS）走势更可能趋向一致。
# 3. 2025年影响人民币汇率最重要的因素依然是我国经济的基本面，预计我国经济增速可
# Extracted context from https://xueqiu.com/3787594483/318278140 (first 200 chars): 各大投行对黄金2025年价格的预测及走势分析：
# - 高盛：预计2025年初金价将达到每盎司2900美元，到2025年底将上涨11%至每盎司3000美元。推动金价走高的因素包括美联储大幅降息、美元走强推动各国央行购买黄金、以及地缘政治冲击推动美元和金价同时上涨。
# - 摩根大通：预计2025年底金价将达到3000美元/盎司。宏观不确定性加剧时，黄金将发挥对冲作用，央行和投资者增持黄金。
# - 瑞银：预计
# Page usefulness for https://opinion.caixin.com/2025-01-13/102278424.html: No
# OpenRouter API error: 504 - {"code":50501,"message":"Model service timeout. Please try again later.","data":null}
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
# LLM did not provide any new search queries. Ending the loop.
#
# Generating final report...
# OpenRouter API error: 429 - {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
#
# ==== FINAL REPORT ====
#
# None
